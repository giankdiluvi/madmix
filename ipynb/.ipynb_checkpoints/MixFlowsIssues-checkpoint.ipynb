# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import sys, time
sys.path.insert(1, '../discrete_mixflows/')
from discrete_mixflows import *

plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams["figure.figsize"]=15,7.5
plt.rcParams.update({'font.size': 24})

# %%
def flow(steps,x,rho,u,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi,direction):
    x_,rho_,u_=np.copy(x),np.copy(rho),np.copy(u)
    lJ=np.zeros(x.shape[1])
    if steps==1: return x_,rho_,u_,lJ
    
    # CACHEING FOR DEBUGGING
    xs=np.zeros((steps,x.shape[0],x.shape[1]))
    xs[0,:,:]=x_
    rhos=np.zeros((steps,rho.shape[0],rho.shape[1]))
    rhos[0,:,:]=rho_
    us=np.zeros((steps,u.shape[0]))
    us[0,:]=u_
    ###
    for n in range(steps-1):
        #print(str(n+1)+'/'+str(steps-1),end='\r')
        print('Iteration: '+str(n+1))
        print()
        if direction=='fwd': x_,rho_,u_,tmplJ=forward(x_,rho_,u_,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi)
        if direction=='bwd': x_,rho_,u_,tmplJ=backward(x_,rho_,u_,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi)
        lJ=lJ+tmplJ
        
        # CACHEING FOR DEBUGGING
        xs[n+1,:,:]=x_
        rhos[n+1,:,:]=rho_
        us[n+1,:]=u_
        ###
        print('=========')
    # end for
    return x_,rho_,u_,lJ,xs,rhos,us

def forward(x,rho,u,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi):
    x_,rho_=Ham(x,rho,L,epsilon,grad_lp,grad_lm)
    lJ=lm(rho_)
    u_=(u+xi)%1
    print('fwd pass')
    print('Initial rho: '+str(rho_[0,0]))
    print('Initial cdf: '+str(Fm(rho_[0,0])))
    #print('pseudorandom: '+str(pseudo_random(x_,u_)[0,0]))
    rho_=Qm((Fm(rho_)+pseudo_random(x_,u_))%1)
    print('Final cdf: '+str(Fm(rho_[0,0])))
    print('Final rho: '+str(rho_[0,0]))
    print()
    lJ=lJ-lm(rho_)
    return x_,rho_,u_,lJ

def backward(x,rho,u,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi):
    x_,rho_,u_=x,rho,u
    lJ=-lm(rho_)
    print('bwd pass')
    print('Final rho: '+str(rho_[0,0]))
    print('Final cdf: '+str(Fm(rho_[0,0])))
    #print('pseudorandom: '+str(pseudo_random(x_,u_)[0,0]))
    rho_=Qm((Fm(rho_)-pseudo_random(x_,u_))%1)
    print('Initial cdf: '+str(Fm(rho_[0,0])))
    print('Initial rho: '+str(rho_[0,0]))
    print()
    lJ=lJ+lm(rho_)
    u_=(u_-xi)%1
    x_,rho_=Ham(x_,rho_,L,-epsilon,grad_lp,grad_lm)
    return x_,rho_,u_,lJ

def Ham(x,rho,L,epsilon,grad_lp,grad_lm):
    x_,rho_=np.copy(x),np.copy(rho)
    print('Hamiltonian dynamics')
    print('Initial x: '+str(x[0,0]))
    print('Initial rho: '+str(rho[0,0]))
    for l in range(L):
        rho_  = rho_ + epsilon*grad_lp(x_)/2
        x_    = x_   - epsilon*grad_lm(rho_)
        rho_  = rho_ + epsilon*grad_lp(x_)/2
    # end for
    print('Final x: '+str(x_[0,0]))
    print('Final rho: '+str(rho_[0,0]))
    print()
    return x_,rho_

def lap_lm(rho): return -np.sum(np.abs(rho),axis=0)-rho.shape[0]*np.log(2) #(M,d)->(d,)
def lap_Fm(rho): return 0.5-0.5*np.sign(rho)*np.expm1(-np.abs(rho))#(1-np.exp(-np.abs(rho))) #(M,d)->(M,d)
def lap_Qm(p)  : return -np.sign(p-0.5)*np.log1p(-2*np.abs(p-0.5)) #(M,d)->(M,d)
def lap_gradlm(rho): return -np.sign(rho) #(M,d)->(M,d)

def gauss_lp(x,mu,sigma): return -0.5*np.sum((x-mu)**2,axis=0)/sigma**2-x.shape[0]*np.log(2*np.pi*sigma**2)/2
def pseudo_random(x,z): return 0.5*np.sin(2*x+u)+0.5

# %%
# target specification
def lp(x): return gauss_lp(x,0,1)
def grad_lp(x): return -x

# ref specification
mu0=100
sigma0=0.3
def lq0(x): return gauss_lp(x,mu0,sigma0)
def randq0(size): return mu0+sigma0*np.random.randn(1,size)

ss=1000
q0_sample=randq0(ss)

# %%
ttx=np.linspace(mu0-4*sigma0,mu0+4*sigma0,1000)
plt.plot(ttx,np.exp(lq0(ttx[np.newaxis,:])))
plt.hist(q0_sample[0,:],alpha=0.5,density=True,bins=50);

# %% [markdown]
# ## Forward pass

# %%
# settings
steps=100
x=q0_sample
rho=np.random.laplace(size=(1,ss))
u=np.random.rand(ss)
L=50
epsilon=0.1
lm,Fm,Qm,grad_lm=lap_lm,lap_Fm,lap_Qm,lap_gradlm
xi=np.pi/16
direction='fwd'

# %%
xp,rhop,up,lJ,xs,rhos,us=flow(steps,x,rho,u,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi,direction)
# Out:
# Iteration: 1
#
# Hamiltonian dynamics
# Initial x: 100.33221492449186
# Initial rho: 0.3378836571377808
# Final x: 95.33221492449215
# Final rho: -488.8231909653222
#
# fwd pass
# Initial rho: -488.8231909653222
# Initial cdf: 0.0
# Final cdf: 0.6748038799668012
# Final rho: 0.43017965183693535
#
# =========
# Iteration: 2
#
# Hamiltonian dynamics
# Initial x: 95.33221492449215
# Initial rho: 0.43017965183693535
# Final x: 90.33221492449243
# Final rho: -463.7308949706245
#
# fwd pass
# Initial rho: -463.7308949706245
# Initial cdf: 0.0
# Final cdf: 0.09848139633454533
# Final rho: -1.6247404377823238
#
# =========
# Iteration: 3
#
# Hamiltonian dynamics
# Initial x: 90.33221492449243
# Initial rho: -1.6247404377823238
# Final x: 85.33221492449272
# Final rho: -440.78581506024534
#
# fwd pass
# Initial rho: -440.78581506024534
# Initial cdf: 0.0
# Final cdf: 0.9990017774938773
# Final rho: 6.216387173916228
#
# =========
# Iteration: 4
#
# Hamiltonian dynamics
# Initial x: 85.33221492449272
# Initial rho: 6.216387173916228
# Final x: 80.53221492449299
# Final rho: -408.93468744854806
#
# fwd pass
# Initial rho: -408.93468744854806
# Initial cdf: 0.0
# Final cdf: 0.003133964084293117
# Final rho: -5.07230941457537
#
# =========
# Iteration: 5
#
# Hamiltonian dynamics
# Initial x: 80.53221492449299
# Initial rho: -5.07230941457537
# Final x: 75.53221492449327
# Final rho: -395.23338403704093
#
# fwd pass
# Initial rho: -395.23338403704093
# Initial cdf: 0.0
# Final cdf: 0.8864986133590642
# Final rho: 1.4827930444746067
#
# =========
# Iteration: 6
#
# Hamiltonian dynamics
# Initial x: 75.53221492449327
# Initial rho: 1.4827930444746067
# Final x: 70.53221492449356
# Final rho: -363.67828157799244
#
# fwd pass
# Initial rho: -363.67828157799244
# Initial cdf: 0.0
# Final cdf: 0.34826607092123063
# Final rho: -0.36164133917096475
#
# =========
# Iteration: 7
#
# Hamiltonian dynamics
# Initial x: 70.53221492449356
# Initial rho: -0.36164133917096475
# Final x: 65.53221492449384
# Final rho: -340.52271596163945
#
# fwd pass
# Initial rho: -340.52271596163945
# Initial cdf: 0.0
# Final cdf: 0.36813262641083166
# Final rho: -0.3061648273254477
#
# =========
# Iteration: 8
#
# Hamiltonian dynamics
# Initial x: 65.53221492449384
# Initial rho: -0.3061648273254477
# Final x: 60.53221492449388
# Final rho: -315.4672394497951
#
# fwd pass
# Initial rho: -315.4672394497951
# Initial cdf: 0.0
# Final cdf: 0.8730262466645304
# Final rho: 1.3706276999719413
#
# =========
# Iteration: 9
#
# Hamiltonian dynamics
# Initial x: 60.53221492449388
# Initial rho: 1.3706276999719413
# Final x: 55.53221492449381
# Final rho: -288.7904469224974
#
# fwd pass
# Initial rho: -288.7904469224974
# Initial cdf: 0.0
# Final cdf: 0.005875967240201507
# Final rho: -4.443737415313048
#
# =========
# Iteration: 10
#
# Hamiltonian dynamics
# Initial x: 55.53221492449381
# Initial rho: -4.443737415313048
# Final x: 50.532214924493736
# Final rho: -269.604812037782
#
# fwd pass
# Initial rho: -269.604812037782
# Initial cdf: 0.0
# Final cdf: 0.9561845687777676
# Final rho: 2.4346220320768697
#
# =========
# Iteration: 11
#
# Hamiltonian dynamics
# Initial x: 50.532214924493736
# Initial rho: 2.4346220320768697
# Final x: 45.532214924493665
# Final rho: -237.7264525903917
#
# fwd pass
# Initial rho: -237.7264525903917
# Initial cdf: 0.0
# Final cdf: 0.22858106542898193
# Final rho: -0.7827171788865971
#
# =========
# Iteration: 12
#
# Hamiltonian dynamics
# Initial x: 45.532214924493665
# Initial rho: -0.7827171788865971
# Final x: 40.532214924493594
# Final rho: -215.9437918013548
#
# fwd pass
# Initial rho: -215.9437918013548
# Initial cdf: 0.0
# Final cdf: 0.49929523212380195
# Final rho: -0.0014105300823870305
#
# =========
# Iteration: 13
#
# Hamiltonian dynamics
# Initial x: 40.532214924493594
# Initial rho: -0.0014105300823870305
# Final x: 35.53221492449352
# Final rho: -190.16248515255015
#
# fwd pass
# Initial rho: -190.16248515255015
# Initial cdf: 0.0
# Final cdf: 0.7726016358900689
# Final rho: 0.7879047110193583
#
# =========
# Iteration: 14
#
# Hamiltonian dynamics
# Initial x: 35.53221492449352
# Initial rho: 0.7879047110193583
# Final x: 30.532214924493452
# Final rho: -164.37316991144814
#
# fwd pass
# Initial rho: -164.37316991144814
# Initial cdf: 0.0
# Final cdf: 0.04324022496619384
# Final rho: -2.447836902931281
#
# =========
# Iteration: 15
#
# Hamiltonian dynamics
# Initial x: 30.532214924493452
# Initial rho: -2.447836902931281
# Final x: 25.53221492449338
# Final rho: -142.60891152539838
#
# fwd pass
# Initial rho: -142.60891152539838
# Initial cdf: 0.0
# Final cdf: 0.9939066098263218
# Final rho: 4.407403492823644
#
# =========
# Iteration: 16
#
# Hamiltonian dynamics
# Initial x: 25.53221492449338
# Initial rho: 4.407403492823644
# Final x: 20.932214924493316
# Final rho: -112.71367112964307
#
# fwd pass
# Initial rho: -112.71367112964307
# Initial cdf: 0.0
# Final cdf: 0.0011725571195208562
# Final rho: -6.055421162261221
#
# =========
# Iteration: 17
#
# Hamiltonian dynamics
# Initial x: 20.932214924493316
# Initial rho: -6.055421162261221
# Final x: 15.932214924493246
# Final rho: -98.21649578472766
#
# fwd pass
# Initial rho: -98.21649578472766
# Initial cdf: 0.0
# Final cdf: 0.9371696893541712
# Final rho: 2.074170487791821
#
# =========
# Iteration: 18
#
# Hamiltonian dynamics
# Initial x: 15.932214924493246
# Initial rho: 2.074170487791821
# Final x: 11.132214924493264
# Final rho: -66.07690413467446
#
# fwd pass
# Initial rho: -66.07690413467446
# Initial cdf: 0.0
# Final cdf: 0.11182601703128142
# Final rho: -1.4976638542974978
#
# =========
# Iteration: 19
#
# Hamiltonian dynamics
# Initial x: 11.132214924493264
# Initial rho: -1.4976638542974978
# Final x: 6.132214924493281
# Final rho: -44.658738476763865
#
# fwd pass
# Initial rho: -44.658738476763865
# Initial cdf: 0.0
# Final cdf: 0.654256244527335
# Final rho: 0.36891018885700977
#
# =========
# Iteration: 20
#
# Hamiltonian dynamics
# Initial x: 6.132214924493281
# Initial rho: 0.36891018885700977
# Final x: 1.3322149244932864
# Final rho: -18.782164433609417
#
# fwd pass
# Initial rho: -18.782164433609417
# Initial cdf: 3.4832097761672287e-09
# Final cdf: 0.43101733869436404
# Final rho: -0.14845978013836433
#
# =========
# Iteration: 21
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: -0.14845978013836433
# Final x: 0.7322149244932861
# Final rho: 0.8504655973952038
#
# fwd pass
# Initial rho: 0.8504655973952038
# Initial cdf: 0.7863920125048725
# Final cdf: 0.7229586345819599
# Final rho: 0.5904412697448771
#
# =========
# Iteration: 22
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932861
# Initial rho: 0.5904412697448771
# Final x: 0.3322149244932861
# Final rho: 0.899366647278447
#
# fwd pass
# Initial rho: 0.899366647278447
# Initial cdf: 0.7965863783484444
# Final cdf: 0.7755942306662735
# Final rho: 0.8011522150608037
#
# =========
# Iteration: 23
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932861
# Initial rho: 0.8011522150608037
# Final x: -0.06778507550671392
# Final rho: 0.9500775925943734
#
# fwd pass
# Initial rho: 0.9500775925943734
# Initial cdf: 0.8066444918103404
# Final cdf: 0.5375338388128688
# Final rho: 0.0780347091471984
#
# =========
# Iteration: 24
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671392
# Initial rho: 0.0780347091471984
# Final x: 0.1322149244932861
# Final rho: 0.07696008668076788
#
# fwd pass
# Initial rho: 0.07696008668076788
# Initial cdf: 0.5370365951593444
# Final cdf: 0.42240586165883
# Final rho: -0.16864148909321022
#
# =========
# Iteration: 25
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932861
# Initial rho: -0.16864148909321022
# Final x: -0.2677850755067139
# Final rho: -0.17971611155964085
#
# fwd pass
# Initial rho: -0.17971611155964085
# Initial cdf: 0.4177536843151859
# Final cdf: 0.957710760725352
# Final rho: 2.4700754354030146
#
# =========
# Iteration: 26
#
# Hamiltonian dynamics
# Initial x: -0.2677850755067139
# Initial rho: 2.4700754354030146
# Final x: -0.26778507550671377
# Final rho: -2.440999187063417
#
# fwd pass
# Initial rho: -2.440999187063417
# Initial cdf: 0.04353690248093728
# Final cdf: 0.5834939788911035
# Final rho: 0.18270718047585868
#
# =========
# Iteration: 27
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671377
# Initial rho: 0.18270718047585868
# Final x: 0.1322149244932862
# Final rho: 0.17163255800942756
#
# fwd pass
# Initial rho: 0.17163255800942756
# Initial cdf: 0.5788556957409008
# Final cdf: 0.46422496224038623
# Final rho: -0.07423883127457129
#
# =========
# Iteration: 28
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932862
# Initial rho: -0.07423883127457129
# Final x: -0.06778507550671375
# Final rho: -0.07531345374100233
#
# fwd pass
# Initial rho: -0.07531345374100233
# Initial cdf: 0.4637263636171081
# Final cdf: 0.19461571061963645
# Final rho: -0.9435811990429039
#
# =========
# Iteration: 29
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: -0.9435811990429039
# Final x: 0.33221492449328627
# Final rho: -0.7946558215093342
#
# fwd pass
# Initial rho: -0.7946558215093342
# Initial cdf: 0.22586834311020143
# Final cdf: 0.2048761954280307
# Final rho: -0.8922022264610993
#
# =========
# Iteration: 30
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: -0.8922022264610993
# Final x: 0.7322149244932862
# Final rho: -0.5832768489275293
#
# fwd pass
# Initial rho: -0.5832768489275293
# Initial cdf: 0.27903333347194637
# Final cdf: 0.21559995554903377
# Final rho: -0.8411834655606837
#
# =========
# Iteration: 31
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: -0.8411834655606837
# Final x: 1.3322149244932864
# Final rho: 0.1577419119728845
#
# fwd pass
# Initial rho: 0.1577419119728845
# Initial cdf: 0.5729649105930834
# Final cdf: 0.003982245804237561
# Final rho: -4.832762165846167
#
# =========
# Iteration: 32
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: -4.832762165846167
# Final x: -3.0677850755067153
# Final rho: 0.9161632116874051
#
# fwd pass
# Initial rho: 0.9161632116874051
# Initial cdf: 0.7999744943364411
# Final cdf: 0.6455876839802628
# Final rho: 0.3441471285463997
#
# =========
# Iteration: 33
#
# Hamiltonian dynamics
# Initial x: -3.0677850755067153
# Initial rho: 0.3441471285463997
# Final x: 1.9322149244932871
# Final rho: 3.183072506079972
#
# fwd pass
# Initial rho: 3.183072506079972
# Initial cdf: 0.9792709604837546
# Final cdf: 0.9927115313852608
# Final rho: 4.228314641033965
#
# =========
# Iteration: 34
#
# Hamiltonian dynamics
# Initial x: 1.9322149244932871
# Initial rho: 4.228314641033965
# Final x: 0.13221492449328626
# Final rho: -6.372759981432469
#
# fwd pass
# Initial rho: -6.372759981432469
# Initial cdf: 0.0008537201065412781
# Final cdf: 0.8862229866060268
# Final rho: 1.480367588398558
#
# =========
# Iteration: 35
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: 1.480367588398558
# Final x: -1.6677850755067143
# Final rho: -0.12070703406787427
#
# fwd pass
# Initial rho: -0.12070703406787427
# Initial cdf: 0.4431467876925886
# Final cdf: 0.7385399505312218
# Final rho: 0.6483266010864066
#
# =========
# Iteration: 36
#
# Hamiltonian dynamics
# Initial x: -1.6677850755067143
# Initial rho: 0.6483266010864066
# Final x: 0.7322149244932862
# Final rho: -1.822748021380025
#
# fwd pass
# Initial rho: -1.822748021380025
# Initial cdf: 0.08079055596238183
# Final cdf: 0.017357178039469012
# Final rho: -3.3606019577336634
#
# =========
# Iteration: 37
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: -3.3606019577336634
# Final x: -1.0677850755067135
# Final rho: 2.9183234197999077
#
# fwd pass
# Initial rho: 2.9183234197999077
# Initial cdf: 0.9729879063516731
# Final cdf: 0.9736328205815987
# Final rho: 2.9424880655373404
#
# =========
# Iteration: 38
#
# Hamiltonian dynamics
# Initial x: -1.0677850755067135
# Initial rho: 2.9424880655373404
# Final x: 1.3322149244932864
# Final rho: -2.528586556929093
#
# fwd pass
# Initial rho: -2.528586556929093
# Initial cdf: 0.03988584669295209
# Final cdf: 0.47090318190410635
# Final rho: -0.059955584125844404
#
# =========
# Iteration: 39
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: -0.059955584125844404
# Final x: 0.932214924493286
# Final rho: 0.4889697934077255
#
# fwd pass
# Initial rho: 0.4889697934077255
# Initial cdf: 0.6933710744279905
# Final cdf: 0.5005584175029898
# Final rho: 0.0011174591309345526
#
# =========
# Iteration: 40
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: 0.0011174591309345526
# Final x: -0.06778507550671375
# Final rho: -0.559957163335496
#
# fwd pass
# Initial rho: -0.559957163335496
# Initial cdf: 0.2856167665319653
# Final cdf: 0.016506113534493716
# Final rho: -3.4108772688981763
#
# =========
# Iteration: 41
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: -3.4108772688981763
# Final x: -0.0677850755067137
# Final rho: 3.1780481086353944
#
# fwd pass
# Initial rho: 3.1780481086353944
# Initial cdf: 0.9791665474639808
# Final cdf: 0.7100558944665094
# Final rho: 0.5449199335580117
#
# =========
# Iteration: 42
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: 0.5449199335580117
# Final x: 0.7322149244932863
# Final rho: 0.3538453110915811
#
# fwd pass
# Initial rho: 0.3538453110915811
# Initial cdf: 0.6490082259870815
# Final cdf: 0.5855748480641689
# Final rho: 0.18771571449292768
#
# =========
# Iteration: 43
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: 0.18771571449292768
# Final x: -0.46778507550671367
# Final rho: -0.24335890797350407
#
# fwd pass
# Initial rho: -0.24335890797350407
# Initial cdf: 0.39199504148938524
# Final cdf: 0.7347115035184508
# Final rho: 0.633790198634912
#
# =========
# Iteration: 44
#
# Hamiltonian dynamics
# Initial x: -0.46778507550671367
# Initial rho: 0.633790198634912
# Final x: -0.46778507550671367
# Final rho: 0.7227155761684805
#
# fwd pass
# Initial rho: 0.7227155761684805
# Initial cdf: 0.757283881874023
# Final cdf: 0.10000034390308854
# Final rho: -1.6094344734091284
#
# =========
# Iteration: 45
#
# Hamiltonian dynamics
# Initial x: -0.46778507550671367
# Initial rho: -1.6094344734091284
# Final x: 1.732214924493287
# Final rho: 0.26949090412443966
#
# fwd pass
# Initial rho: 0.26949090412443966
# Initial cdf: 0.6181158866842422
# Final cdf: 0.7148071728351721
# Final rho: 0.561442560391773
#
# =========
# Iteration: 46
#
# Hamiltonian dynamics
# Initial x: 1.732214924493287
# Initial rho: 0.561442560391773
# Final x: -1.4677850755067139
# Final rho: 1.1303679379253415
#
# fwd pass
# Initial rho: 1.1303679379253415
# Initial cdf: 0.8385427889503818
# Final cdf: 0.9724272518028669
# Final rho: 2.897780197645788
#
# =========
# Iteration: 47
#
# Hamiltonian dynamics
# Initial x: -1.4677850755067139
# Initial rho: 2.897780197645788
# Final x: 2.132214924493287
# Final rho: -1.7732944248206448
#
# fwd pass
# Initial rho: -1.7732944248206448
# Initial cdf: 0.08488638145850291
# Final cdf: 0.09189327249370294
# Final rho: -1.6939802763788465
#
# =========
# Iteration: 48
#
# Hamiltonian dynamics
# Initial x: 2.132214924493287
# Initial rho: -1.6939802763788465
# Final x: -2.667785075506715
# Final rho: 0.13494510115472377
#
# fwd pass
# Initial rho: 0.13494510115472377
# Initial cdf: 0.5631180605003258
# Final cdf: 0.5631035765993295
# Final rho: 0.1349119488094323
#
# =========
# Iteration: 49
#
# Hamiltonian dynamics
# Initial x: -2.667785075506715
# Initial rho: 0.1349119488094323
# Final x: 2.3322149244932873
# Final rho: 0.9738373263430016
#
# fwd pass
# Initial rho: 0.9738373263430016
# Initial cdf: 0.8111844198893474
# Final cdf: 0.8895904030284589
# Final rho: 1.5104110392672654
#
# =========
# Iteration: 50
#
# Hamiltonian dynamics
# Initial x: 2.3322149244932873
# Initial rho: 1.5104110392672654
# Final x: -1.467785075506714
# Final rho: -3.2906635831991657
#
# fwd pass
# Initial rho: -3.2906635831991657
# Initial cdf: 0.018614568284033906
# Final cdf: 0.15249903113651914
# Final rho: -1.1874498555980604
#
# =========
# Iteration: 51
#
# Hamiltonian dynamics
# Initial x: -1.467785075506714
# Initial rho: -1.1874498555980604
# Final x: 2.132214924493287
# Final rho: 0.16147552193550907
#
# fwd pass
# Initial rho: 0.16147552193550907
# Initial cdf: 0.5745563203569424
# Final cdf: 0.5815632113921424
# Final rho: 0.17808226265379554
#
# =========
# Iteration: 52
#
# Hamiltonian dynamics
# Initial x: 2.132214924493287
# Initial rho: 0.17808226265379554
# Final x: -1.8677850755067142
# Final rho: 0.8670076401873649
#
# fwd pass
# Initial rho: 0.8670076401873649
# Initial cdf: 0.7898964597045208
# Final cdf: 0.27910124322076557
# Final rho: -0.5830335034979852
#
# =========
# Iteration: 53
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: -0.5830335034979852
# Final x: 1.7322149244932867
# Final rho: -0.6741081259644168
#
# fwd pass
# Initial rho: -0.6741081259644168
# Initial cdf: 0.25480536328043357
# Final cdf: 0.3514966494313635
# Final rho: -0.3524079194178612
#
# =========
# Iteration: 54
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: -0.3524079194178612
# Final x: -0.6677850755067138
# Final rho: 1.796517458115708
#
# fwd pass
# Initial rho: 1.796517458115708
# Initial cdf: 0.9170622239657873
# Final cdf: 0.08736968390802202
# Final rho: -1.74445974197358
#
# =========
# Iteration: 55
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067138
# Initial rho: -1.74445974197358
# Final x: 1.7322149244932867
# Final rho: 0.4044656355599898
#
# fwd pass
# Initial rho: 0.4044656355599898
# Initial cdf: 0.6663333426042312
# Final cdf: 0.7630246287551611
# Final rho: 0.746651881485141
#
# =========
# Iteration: 56
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.746651881485141
# Final x: -1.8677850755067142
# Final rho: 0.6555772590187094
#
# fwd pass
# Initial rho: 0.6555772590187094
# Initial cdf: 0.7404288517493074
# Final cdf: 0.22963363526555214
# Final rho: -0.7781229496471087
#
# =========
# Iteration: 57
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: -0.7781229496471087
# Final x: 2.3322149244932873
# Final rho: -0.09919757211354005
#
# fwd pass
# Initial rho: -0.09919757211354005
# Initial cdf: 0.4527818880994761
# Final cdf: 0.5311878712385876
# Final rho: 0.06440598856272102
#
# =========
# Iteration: 58
#
# Hamiltonian dynamics
# Initial x: 2.3322149244932873
# Initial rho: 0.06440598856272102
# Final x: -1.8677850755067142
# Final rho: 0.7433313660962896
#
# fwd pass
# Initial rho: 0.7433313660962896
# Initial cdf: 0.7622364405167782
# Final cdf: 0.25144122403302305
# Final rho: -0.6873988378528457
#
# =========
# Iteration: 59
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: -0.6873988378528457
# Final x: 1.7322149244932867
# Final rho: -0.7784734603192777
#
# fwd pass
# Initial rho: -0.7784734603192777
# Initial cdf: 0.22955316033018835
# Final cdf: 0.3262444464811183
# Final rho: -0.4269611622102665
#
# =========
# Iteration: 60
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: -0.4269611622102665
# Final x: -0.6677850755067138
# Final rho: 1.721964215323303
#
# fwd pass
# Initial rho: 1.721964215323303
# Initial cdf: 0.9106426156774385
# Final cdf: 0.08095007561967327
# Final rho: -1.8207754841461332
#
# =========
# Iteration: 61
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067138
# Initial rho: -1.8207754841461332
# Final x: 1.5322149244932868
# Final rho: 1.0581498933874363
#
# fwd pass
# Initial rho: 1.0581498933874363
# Initial cdf: 0.8264513080888063
# Final cdf: 0.07006688745160106
# Final rho: -1.9651577775829425
#
# =========
# Iteration: 62
#
# Hamiltonian dynamics
# Initial x: 1.5322149244932868
# Initial rho: -1.9651577775829425
# Final x: -1.4677850755067139
# Final rho: 1.8737675999506274
#
# fwd pass
# Initial rho: 1.8737675999506274
# Initial cdf: 0.9232279609899925
# Final cdf: 0.05711242384247761
# Final rho: -2.169586424998736
#
# =========
# Iteration: 63
#
# Hamiltonian dynamics
# Initial x: -1.4677850755067139
# Initial rho: -2.169586424998736
# Final x: 1.3322149244932866
# Final rho: 2.4593389525348353
#
# fwd pass
# Initial rho: 2.4593389525348353
# Initial cdf: 0.9572542769019744
# Final cdf: 0.38827161211312844
# Final rho: -0.25290297248708055
#
# =========
# Iteration: 64
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932866
# Initial rho: -0.25290297248708055
# Final x: 0.7322149244932863
# Final rho: 0.7460224050464865
#
# fwd pass
# Initial rho: 0.7460224050464865
# Initial cdf: 0.7628754113829381
# Final cdf: 0.6994420334600253
# Final rho: 0.5089674627503833
#
# =========
# Iteration: 65
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: 0.5089674627503833
# Final x: 0.7322149244932863
# Final rho: 0.5978928402839521
#
# fwd pass
# Initial rho: 0.5978928402839521
# Initial cdf: 0.7250153554415669
# Final cdf: 0.6615819775186542
# Final rho: 0.3903262141846777
#
# =========
# Iteration: 66
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: 0.3903262141846777
# Final x: 1.1322149244932864
# Final rho: 0.09925159171824682
#
# fwd pass
# Initial rho: 0.09925159171824682
# Initial cdf: 0.5472425703385139
# Final cdf: 0.1765525073769545
# Final rho: -1.0409897740701715
#
# =========
# Iteration: 67
#
# Hamiltonian dynamics
# Initial x: 1.1322149244932864
# Initial rho: -1.0409897740701715
# Final x: 0.1322149244932863
# Final rho: 1.7979356034633969
#
# fwd pass
# Initial rho: 1.7979356034633969
# Initial cdf: 0.9171797584268451
# Final cdf: 0.8025490249263307
# Final rho: 0.9291177723696464
#
# =========
# Iteration: 68
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932863
# Initial rho: 0.9291177723696464
# Final x: -0.0677850755067137
# Final rho: 0.7680431499032148
#
# fwd pass
# Initial rho: 0.7680431499032148
# Initial cdf: 0.7680399987217295
# Final cdf: 0.49892934572425807
# Final rho: -0.002143604430682877
#
# =========
# Iteration: 69
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.002143604430682877
# Final x: -0.0677850755067137
# Final rho: -0.03321822689711441
#
# fwd pass
# Initial rho: -0.03321822689711441
# Initial cdf: 0.48366371984409634
# Final cdf: 0.2145530668466249
# Final rho: -0.8460509927655676
#
# =========
# Iteration: 70
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.8460509927655676
# Final x: -0.06778507550671353
# Final rho: -0.7571256152319985
#
# fwd pass
# Initial rho: -0.7571256152319985
# Initial cdf: 0.2345063070335694
# Final cdf: 0.965395654036098
# Final rho: 2.67062881835315
#
# =========
# Iteration: 71
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671353
# Initial rho: 2.67062881835315
# Final x: -0.26778507550671377
# Final rho: -2.730445804113284
#
# fwd pass
# Initial rho: -2.730445804113284
# Initial cdf: 0.03259511056022424
# Final cdf: 0.5725521869703905
# Final rho: 0.15677589228164887
#
# =========
# Iteration: 72
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671377
# Initial rho: 0.15677589228164887
# Final x: -0.6677850755067137
# Final rho: -0.07429873018478239
#
# fwd pass
# Initial rho: -0.07429873018478239
# Initial cdf: 0.4641971565038302
# Final cdf: 0.634504616446065
# Final rho: 0.3133544498075139
#
# =========
# Iteration: 73
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067137
# Initial rho: 0.3133544498075139
# Final x: 0.1322149244932861
# Final rho: 0.602279827341084
#
# fwd pass
# Initial rho: 0.602279827341084
# Initial cdf: 0.7262190672535669
# Final cdf: 0.6115883337530523
# Final rho: 0.25254232577499225
#
# =========
# Iteration: 74
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932861
# Initial rho: 0.25254232577499225
# Final x: -0.4677850755067139
# Final rho: -0.26853229669143813
#
# fwd pass
# Initial rho: -0.26853229669143813
# Initial cdf: 0.38225036578344973
# Final cdf: 0.7249668278125151
# Final rho: 0.5977163818940591
#
# =========
# Iteration: 75
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067139
# Initial rho: 0.5977163818940591
# Final x: -0.4677850755067139
# Final rho: 0.6866417594276293
#
# fwd pass
# Initial rho: 0.6866417594276293
# Initial cdf: 0.748368343163864
# Final cdf: 0.09108480519292939
# Final rho: -1.702817100681003
#
# =========
# Iteration: 76
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067139
# Initial rho: -1.702817100681003
# Final x: 1.7322149244932867
# Final rho: 0.17610827685256614
#
# fwd pass
# Initial rho: 0.17610827685256614
# Initial cdf: 0.5807364073314588
# Final cdf: 0.6774276934823887
# Final rho: 0.43828078106067203
#
# =========
# Iteration: 77
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.43828078106067203
# Final x: -0.8677850755067138
# Final rho: 1.3172061585942405
#
# fwd pass
# Initial rho: 1.3172061585942405
# Initial cdf: 0.8660586604130116
# Final cdf: 0.9160083210620636
# Final rho: 1.7838903647483324
#
# =========
# Iteration: 78
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067138
# Initial rho: 1.7838903647483324
# Final x: -0.06778507550671375
# Final rho: -1.9671842577180993
#
# fwd pass
# Initial rho: -1.9671842577180993
# Initial cdf: 0.06992504206801625
# Final cdf: 0.8008143890705446
# Final rho: 0.9203709901705983
#
# =========
# Iteration: 79
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: 0.9203709901705983
# Final x: -0.26778507550671393
# Final rho: 0.7192963677041682
#
# fwd pass
# Initial rho: 0.7192963677041682
# Initial cdf: 0.756452564454633
# Final cdf: 0.29640964086479915
# Final rho: -0.522865678994826
#
# =========
# Iteration: 80
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671393
# Initial rho: -0.522865678994826
# Final x: -0.8677850755067137
# Final rho: 0.07605969853874342
#
# fwd pass
# Initial rho: 0.07605969853874342
# Initial cdf: 0.5366195606811593
# Final cdf: 0.5865692213302115
# Final rho: 0.19011800143076316
#
# =========
# Iteration: 81
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067137
# Initial rho: 0.19011800143076316
# Final x: 0.1322149244932862
# Final rho: 0.4290433789643323
#
# fwd pass
# Initial rho: 0.4290433789643323
# Initial cdf: 0.6744341584248319
# Final cdf: 0.5598034249243173
# Final rho: 0.12738670974246338
#
# =========
# Iteration: 82
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932862
# Initial rho: 0.12738670974246338
# Final x: 0.3322149244932862
# Final rho: 0.1663120872760322
#
# fwd pass
# Initial rho: 0.1663120872760322
# Initial cdf: 0.576609038458145
# Final cdf: 0.5556168907759744
# Final rho: 0.11792104942578806
#
# =========
# Iteration: 83
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932862
# Initial rho: 0.11792104942578806
# Final x: 0.3322149244932862
# Final rho: 0.08684642695935683
#
# fwd pass
# Initial rho: 0.08684642695935683
# Initial cdf: 0.5415910583338313
# Final cdf: 0.5205989106516606
# Final rho: 0.042070504108387335
#
# =========
# Iteration: 84
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932862
# Initial rho: 0.042070504108387335
# Final x: -0.06778507550671375
# Final rho: -0.22900411835804377
#
# fwd pass
# Initial rho: -0.22900411835804377
# Initial cdf: 0.39766262903208766
# Final cdf: 0.1285519760346161
# Final rho: -1.3582747931083583
#
# =========
# Iteration: 85
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: -1.3582747931083583
# Final x: 1.7322149244932867
# Final rho: -0.07934941557478999
#
# fwd pass
# Initial rho: -0.07934941557478999
# Initial cdf: 0.4618585534528902
# Final cdf: 0.5585498396038201
# Final rho: 0.12454297173526226
#
# =========
# Iteration: 86
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.12454297173526226
# Final x: -0.6677850755067138
# Final rho: 1.533468349268831
#
# fwd pass
# Initial rho: 1.533468349268831
# Initial cdf: 0.8921070265548495
# Final cdf: 0.062414486497084365
# Final rho: -2.080810694588712
#
# =========
# Iteration: 87
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067138
# Initial rho: -2.080810694588712
# Final x: 1.3322149244932866
# Final rho: 1.5081146829448577
#
# fwd pass
# Initial rho: 1.5081146829448577
# Initial cdf: 0.8893365719206072
# Final cdf: 0.32035390713176115
# Final rho: -0.44518175396464743
#
# =========
# Iteration: 88
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932866
# Initial rho: -0.44518175396464743
# Final x: 0.3322149244932863
# Final rho: 1.3937436235689196
#
# fwd pass
# Initial rho: 1.3937436235689196
# Initial cdf: 0.875927698182567
# Final cdf: 0.8549355505003964
# Final rho: 1.2374299754456726
#
# =========
# Iteration: 89
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932863
# Initial rho: 1.2374299754456726
# Final x: -1.2677850755067137
# Final rho: 0.606355352979239
#
# fwd pass
# Initial rho: 0.606355352979239
# Initial cdf: 0.7273325978117406
# Final cdf: 0.7575099538431271
# Final rho: 0.7236474356628778
#
# =========
# Iteration: 90
#
# Hamiltonian dynamics
# Initial x: -1.2677850755067137
# Initial rho: 0.7236474356628778
# Final x: -0.26778507550671354
# Final rho: -1.4374271868035555
#
# fwd pass
# Initial rho: -1.4374271868035555
# Initial cdf: 0.11876905718758662
# Final cdf: 0.658726133597753
# Final rho: 0.3819228161934996
#
# =========
# Iteration: 91
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671354
# Initial rho: 0.3819228161934996
# Final x: 0.9322149244932864
# Final rho: 0.05084819372706734
#
# fwd pass
# Initial rho: 0.05084819372706734
# Initial cdf: 0.5247885301270717
# Final cdf: 0.3319758732020708
# Final rho: -0.409545803224474
#
# =========
# Iteration: 92
#
# Hamiltonian dynamics
# Initial x: 0.9322149244932864
# Initial rho: -0.409545803224474
# Final x: 0.9322149244932864
# Final rho: -0.32062042569090526
#
# fwd pass
# Initial rho: -0.32062042569090526
# Initial cdf: 0.3628493276421639
# Final cdf: 0.170036670717163
# Final rho: -1.0785939745330497
#
# =========
# Iteration: 93
#
# Hamiltonian dynamics
# Initial x: 0.9322149244932864
# Initial rho: -1.0785939745330497
# Final x: 0.5322149244932863
# Final rho: 1.470331403000518
#
# fwd pass
# Initial rho: 1.470331403000518
# Initial cdf: 0.8850753500921176
# Final cdf: 0.8820969807747261
# Final rho: 1.444745682849894
#
# =========
# Iteration: 94
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932863
# Initial rho: 1.444745682849894
# Final x: -1.2677850755067137
# Final rho: 0.5636710603834609
#
# fwd pass
# Initial rho: 0.5636710603834609
# Initial cdf: 0.7154420174098427
# Final cdf: 0.7456193734412292
# Final rho: 0.6757764233199982
#
# =========
# Iteration: 95
#
# Hamiltonian dynamics
# Initial x: -1.2677850755067137
# Initial rho: 0.6757764233199982
# Final x: -0.26778507550671354
# Final rho: -1.4852981991464353
#
# fwd pass
# Initial rho: -1.4852981991464353
# Initial cdf: 0.1132174039707079
# Final cdf: 0.6531744803808743
# Final rho: 0.3657862702394826
#
# =========
# Iteration: 96
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671354
# Initial rho: 0.3657862702394826
# Final x: 0.9322149244932864
# Final rho: 0.0347116477730503
#
# fwd pass
# Initial rho: 0.0347116477730503
# Initial cdf: 0.5170580545614211
# Final cdf: 0.32424539763642013
# Final rho: -0.4331074692001731
#
# =========
# Iteration: 97
#
# Hamiltonian dynamics
# Initial x: 0.9322149244932864
# Initial rho: -0.4331074692001731
# Final x: 1.3322149244932866
# Final rho: 0.11581790833339502
#
# fwd pass
# Initial rho: 0.11581790833339502
# Initial cdf: 0.5546813069106201
# Final cdf: 0.9856986421217742
# Final rho: 3.5542536091451256
#
# =========
# Iteration: 98
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932866
# Initial rho: 3.5542536091451256
# Final x: -0.4677850755067138
# Final rho: -4.046821013321307
#
# fwd pass
# Initial rho: -4.046821013321307
# Initial cdf: 0.008738924132311754
# Final cdf: 0.3514553861613772
# Final rho: -0.35252531937673287
#
# =========
# Iteration: 99
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067138
# Initial rho: -0.35252531937673287
# Final x: -0.06778507550671381
# Final rho: 0.3564000581568359
#
# fwd pass
# Initial rho: 0.3564000581568359
# Initial cdf: 0.6499037767517407
# Final cdf: 0.3807931237542692
# Final rho: -0.27235185303600823
#
# =========

# %%
xpp,rhopp,upp,lJ,xps,rhops,ups=flow(steps,xp,rhop,up,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi,direction='bwd')
# Out:
# Iteration: 1
#
# bwd pass
# Final rho: -0.27235185303600823
# Final cdf: 0.3807931237542692
# Initial cdf: 0.6499037767517408
# Initial rho: 0.35640005815683623
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671381
# Initial rho: 0.35640005815683623
# Final x: -0.4677850755067138
# Final rho: -0.35252531937673254
#
# =========
# Iteration: 2
#
# bwd pass
# Final rho: -0.35252531937673254
# Final cdf: 0.35145538616137734
# Initial cdf: 0.008738924132311865
# Initial rho: -4.046821013321293
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067138
# Initial rho: -4.046821013321293
# Final x: 1.3322149244932864
# Final rho: 3.5542536091451393
#
# =========
# Iteration: 3
#
# bwd pass
# Final rho: 3.5542536091451393
# Final cdf: 0.9856986421217744
# Initial cdf: 0.5546813069106201
# Initial rho: 0.11581790833339513
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: 0.11581790833339513
# Final x: 0.932214924493286
# Final rho: -0.4331074692001746
#
# =========
# Iteration: 4
#
# bwd pass
# Final rho: -0.4331074692001746
# Final cdf: 0.3242453976364197
# Initial cdf: 0.5170580545614203
# Initial rho: 0.034711647773048686
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: 0.034711647773048686
# Final x: -0.2677850755067139
# Final rho: 0.36578627023947924
#
# =========
# Iteration: 5
#
# bwd pass
# Final rho: 0.36578627023947924
# Final cdf: 0.6531744803808732
# Initial cdf: 0.11321740397070712
# Initial rho: -1.4852981991464425
#
# Hamiltonian dynamics
# Initial x: -0.2677850755067139
# Initial rho: -1.4852981991464425
# Final x: -1.267785075506714
# Final rho: 0.67577642331999
#
# =========
# Iteration: 6
#
# bwd pass
# Final rho: 0.67577642331999
# Final cdf: 0.7456193734412271
# Initial cdf: 0.7154420174098406
# Initial rho: 0.5636710603834536
#
# Hamiltonian dynamics
# Initial x: -1.267785075506714
# Initial rho: 0.5636710603834536
# Final x: 0.5322149244932862
# Final rho: 1.444745682849885
#
# =========
# Iteration: 7
#
# bwd pass
# Final rho: 1.444745682849885
# Final cdf: 0.882096980774725
# Initial cdf: 0.8850753500921165
# Initial rho: 1.4703314030005088
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932862
# Initial rho: 1.4703314030005088
# Final x: 0.932214924493286
# Final rho: -1.0785939745330597
#
# =========
# Iteration: 8
#
# bwd pass
# Final rho: -1.0785939745330597
# Final cdf: 0.17003667071716133
# Initial cdf: 0.36284932764216193
# Initial rho: -0.3206204256909106
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: -0.3206204256909106
# Final x: 0.932214924493286
# Final rho: -0.40954580322448075
#
# =========
# Iteration: 9
#
# bwd pass
# Final rho: -0.40954580322448075
# Final cdf: 0.33197587320206856
# Initial cdf: 0.5247885301270692
# Initial rho: 0.05084819372706201
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: 0.05084819372706201
# Final x: -0.2677850755067139
# Final rho: 0.3819228161934924
#
# =========
# Iteration: 10
#
# bwd pass
# Final rho: 0.3819228161934924
# Final cdf: 0.6587261335977506
# Initial cdf: 0.11876905718758446
# Initial rho: -1.4374271868035737
#
# Hamiltonian dynamics
# Initial x: -0.2677850755067139
# Initial rho: -1.4374271868035737
# Final x: -1.267785075506714
# Final rho: 0.7236474356628587
#
# =========
# Iteration: 11
#
# bwd pass
# Final rho: 0.7236474356628587
# Final cdf: 0.7575099538431225
# Initial cdf: 0.727332597811736
# Initial rho: 0.6063553529792219
#
# Hamiltonian dynamics
# Initial x: -1.267785075506714
# Initial rho: 0.6063553529792219
# Final x: 0.33221492449328627
# Final rho: 1.2374299754456541
#
# =========
# Iteration: 12
#
# bwd pass
# Final rho: 1.2374299754456541
# Final cdf: 0.8549355505003937
# Initial cdf: 0.8759276981825643
# Initial rho: 1.3937436235688976
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: 1.3937436235688976
# Final x: 1.3322149244932864
# Final rho: -0.4451817539646703
#
# =========
# Iteration: 13
#
# bwd pass
# Final rho: -0.4451817539646703
# Final cdf: 0.3203539071317538
# Initial cdf: 0.8893365719205996
# Initial rho: 1.5081146829447893
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: 1.5081146829447893
# Final x: -0.6677850755067136
# Final rho: -2.0808106945887808
#
# =========
# Iteration: 14
#
# bwd pass
# Final rho: -2.0808106945887808
# Final cdf: 0.06241448649708009
# Initial cdf: 0.8921070265548452
# Initial rho: 1.5334683492687908
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067136
# Initial rho: 1.5334683492687908
# Final x: 1.732214924493287
# Final rho: 0.1245429717352231
#
# =========
# Iteration: 15
#
# bwd pass
# Final rho: 0.1245429717352231
# Final cdf: 0.5585498396038028
# Initial cdf: 0.46185855345287286
# Initial rho: -0.07934941557482753
#
# Hamiltonian dynamics
# Initial x: 1.732214924493287
# Initial rho: -0.07934941557482753
# Final x: -0.0677850755067137
# Final rho: -1.3582747931083945
#
# =========
# Iteration: 16
#
# bwd pass
# Final rho: -1.3582747931083945
# Final cdf: 0.12855197603461144
# Initial cdf: 0.39766262903208294
# Initial rho: -0.22900411835805562
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.22900411835805562
# Final x: 0.3322149244932864
# Final rho: 0.04207050410837601
#
# =========
# Iteration: 17
#
# bwd pass
# Final rho: 0.04207050410837601
# Final cdf: 0.5205989106516552
# Initial cdf: 0.5415910583338258
# Initial rho: 0.08684642695934491
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932864
# Initial rho: 0.08684642695934491
# Final x: 0.3322149244932864
# Final rho: 0.11792104942577658
#
# =========
# Iteration: 18
#
# bwd pass
# Final rho: 0.11792104942577658
# Final cdf: 0.5556168907759693
# Initial cdf: 0.5766090384581399
# Initial rho: 0.16631208727602018
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932864
# Initial rho: 0.16631208727602018
# Final x: 0.13221492449328637
# Final rho: 0.12738670974245186
#
# =========
# Iteration: 19
#
# bwd pass
# Final rho: 0.12738670974245186
# Final cdf: 0.5598034249243122
# Initial cdf: 0.6744341584248266
# Initial rho: 0.4290433789643159
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328637
# Initial rho: 0.4290433789643159
# Final x: -0.8677850755067135
# Final rho: 0.19011800143074709
#
# =========
# Iteration: 20
#
# bwd pass
# Final rho: 0.19011800143074709
# Final cdf: 0.5865692213302048
# Initial cdf: 0.5366195606811526
# Initial rho: 0.0760596985387289
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067135
# Initial rho: 0.0760596985387289
# Final x: -0.2677850755067137
# Final rho: -0.5228656789948398
#
# =========
# Iteration: 21
#
# bwd pass
# Final rho: -0.5228656789948398
# Final cdf: 0.29640964086479504
# Initial cdf: 0.7564525644546287
# Initial rho: 0.7192963677041504
#
# Hamiltonian dynamics
# Initial x: -0.2677850755067137
# Initial rho: 0.7192963677041504
# Final x: -0.06778507550671353
# Final rho: 0.9203709901705814
#
# =========
# Iteration: 22
#
# bwd pass
# Final rho: 0.9203709901705814
# Final cdf: 0.8008143890705413
# Initial cdf: 0.06992504206801264
# Initial rho: -1.9671842577181513
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671353
# Initial rho: -1.9671842577181513
# Final x: -0.8677850755067137
# Final rho: 1.7838903647482809
#
# =========
# Iteration: 23
#
# bwd pass
# Final rho: 1.7838903647482809
# Final cdf: 0.9160083210620593
# Initial cdf: 0.8660586604130072
# Initial rho: 1.3172061585942072
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067137
# Initial rho: 1.3172061585942072
# Final x: 1.7322149244932867
# Final rho: 0.43828078106063845
#
# =========
# Iteration: 24
#
# bwd pass
# Final rho: 0.43828078106063845
# Final cdf: 0.6774276934823779
# Initial cdf: 0.5807364073314479
# Initial rho: 0.17610827685254027
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.17610827685254027
# Final x: -0.4677850755067139
# Final rho: -1.7028171006810284
#
# =========
# Iteration: 25
#
# bwd pass
# Final rho: -1.7028171006810284
# Final cdf: 0.09108480519292705
# Initial cdf: 0.7483683431638617
# Initial rho: 0.6866417594276201
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067139
# Initial rho: 0.6866417594276201
# Final x: -0.4677850755067138
# Final rho: 0.5977163818940496
#
# =========
# Iteration: 26
#
# bwd pass
# Final rho: 0.5977163818940496
# Final cdf: 0.7249668278125125
# Initial cdf: 0.38225036578344707
# Initial rho: -0.268532296691445
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067138
# Initial rho: -0.268532296691445
# Final x: 0.13221492449328626
# Final rho: 0.2525423257749861
#
# =========
# Iteration: 27
#
# bwd pass
# Final rho: 0.2525423257749861
# Final cdf: 0.6115883337530499
# Initial cdf: 0.7262190672535643
# Initial rho: 0.6022798273410744
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: 0.6022798273410744
# Final x: -0.6677850755067137
# Final rho: 0.3133544498075045
#
# =========
# Iteration: 28
#
# bwd pass
# Final rho: 0.3133544498075045
# Final cdf: 0.6345046164460616
# Initial cdf: 0.46419715650382676
# Initial rho: -0.07429873018478984
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067137
# Initial rho: -0.07429873018478984
# Final x: -0.26778507550671377
# Final rho: 0.1567758922816413
#
# =========
# Iteration: 29
#
# bwd pass
# Final rho: 0.1567758922816413
# Final cdf: 0.5725521869703872
# Initial cdf: 0.03259511056022102
# Initial rho: -2.730445804113383
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671377
# Initial rho: -2.730445804113383
# Final x: -0.06778507550671375
# Final rho: 2.6706288183530495
#
# =========
# Iteration: 30
#
# bwd pass
# Final rho: 2.6706288183530495
# Final cdf: 0.9653956540360944
# Initial cdf: 0.234506307033566
# Initial rho: -0.7571256152320129
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: -0.7571256152320129
# Final x: -0.06778507550671392
# Final rho: -0.846050992765583
#
# =========
# Iteration: 31
#
# bwd pass
# Final rho: -0.846050992765583
# Final cdf: 0.21455306684662157
# Initial cdf: 0.4836637198440933
# Initial rho: -0.03321822689712067
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671392
# Initial rho: -0.03321822689712067
# Final x: -0.06778507550671392
# Final rho: -0.002143604430690241
#
# =========
# Iteration: 32
#
# bwd pass
# Final rho: -0.002143604430690241
# Final cdf: 0.4989293457242544
# Initial cdf: 0.7680399987217261
# Initial rho: 0.7680431499032006
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671392
# Initial rho: 0.7680431499032006
# Final x: 0.13221492449328626
# Final rho: 0.9291177723696302
#
# =========
# Iteration: 33
#
# bwd pass
# Final rho: 0.9291177723696302
# Final cdf: 0.8025490249263275
# Initial cdf: 0.917179758426842
# Initial rho: 1.7979356034633587
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: 1.7979356034633587
# Final x: 1.1322149244932862
# Final rho: -1.0409897740702108
#
# =========
# Iteration: 34
#
# bwd pass
# Final rho: -1.0409897740702108
# Final cdf: 0.17655250737694755
# Initial cdf: 0.5472425703385067
# Initial rho: 0.09925159171823085
#
# Hamiltonian dynamics
# Initial x: 1.1322149244932862
# Initial rho: 0.09925159171823085
# Final x: 0.7322149244932862
# Final rho: 0.3903262141846606
#
# =========
# Iteration: 35
#
# bwd pass
# Final rho: 0.3903262141846606
# Final cdf: 0.6615819775186484
# Initial cdf: 0.7250153554415611
# Initial rho: 0.5978928402839312
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.5978928402839312
# Final x: 0.7322149244932862
# Final rho: 0.5089674627503611
#
# =========
# Iteration: 36
#
# bwd pass
# Final rho: 0.5089674627503611
# Final cdf: 0.6994420334600187
# Initial cdf: 0.7628754113829314
# Initial rho: 0.7460224050464577
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.7460224050464577
# Final x: 1.3322149244932864
# Final rho: -0.2529029724871108
#
# =========
# Iteration: 37
#
# bwd pass
# Final rho: -0.2529029724871108
# Final cdf: 0.38827161211311667
# Initial cdf: 0.9572542769019624
# Initial rho: 2.459338952534555
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: 2.459338952534555
# Final x: -1.4677850755067139
# Final rho: -2.169586424999016
#
# =========
# Iteration: 38
#
# bwd pass
# Final rho: -2.169586424999016
# Final cdf: 0.057112423842461624
# Initial cdf: 0.9232279609899765
# Initial rho: 1.8737675999504197
#
# Hamiltonian dynamics
# Initial x: -1.4677850755067139
# Initial rho: 1.8737675999504197
# Final x: 1.5322149244932868
# Final rho: -1.9651577775831504
#
# =========
# Iteration: 39
#
# bwd pass
# Final rho: -1.9651577775831504
# Final cdf: 0.07006688745158651
# Initial cdf: 0.8264513080887917
# Initial rho: 1.058149893387352
#
# Hamiltonian dynamics
# Initial x: 1.5322149244932868
# Initial rho: 1.058149893387352
# Final x: -0.6677850755067136
# Final rho: -1.820775484146217
#
# =========
# Iteration: 40
#
# bwd pass
# Final rho: -1.820775484146217
# Final cdf: 0.0809500756196665
# Initial cdf: 0.9106426156774317
# Initial rho: 1.7219642153232255
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067136
# Initial rho: 1.7219642153232255
# Final x: 1.732214924493287
# Final rho: -0.4269611622103431
#
# =========
# Iteration: 41
#
# bwd pass
# Final rho: -0.4269611622103431
# Final cdf: 0.3262444464810933
# Initial cdf: 0.22955316033016337
# Initial rho: -0.7784734603193866
#
# Hamiltonian dynamics
# Initial x: 1.732214924493287
# Initial rho: -0.7784734603193866
# Final x: -1.8677850755067142
# Final rho: -0.687398837852955
#
# =========
# Iteration: 42
#
# bwd pass
# Final rho: -0.687398837852955
# Final cdf: 0.2514412240329956
# Initial cdf: 0.7622364405167509
# Initial rho: 0.7433313660961746
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.7433313660961746
# Final x: 2.3322149244932873
# Final rho: 0.06440598856260601
#
# =========
# Iteration: 43
#
# bwd pass
# Final rho: 0.06440598856260601
# Final cdf: 0.5311878712385336
# Initial cdf: 0.45278188809942216
# Initial rho: -0.0991975721136592
#
# Hamiltonian dynamics
# Initial x: 2.3322149244932873
# Initial rho: -0.0991975721136592
# Final x: -1.8677850755067142
# Final rho: -0.7781229496472282
#
# =========
# Iteration: 44
#
# bwd pass
# Final rho: -0.7781229496472282
# Final cdf: 0.22963363526552472
# Initial cdf: 0.74042885174928
# Initial rho: 0.6555772590186038
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.6555772590186038
# Final x: 1.7322149244932867
# Final rho: 0.7466518814850355
#
# =========
# Iteration: 45
#
# bwd pass
# Final rho: 0.7466518814850355
# Final cdf: 0.7630246287551361
# Initial cdf: 0.6663333426042062
# Initial rho: 0.40446563555991494
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.40446563555991494
# Final x: -0.6677850755067138
# Final rho: -1.7444597419736545
#
# =========
# Iteration: 46
#
# bwd pass
# Final rho: -1.7444597419736545
# Final cdf: 0.08736968390801553
# Initial cdf: 0.9170622239657809
# Initial rho: 1.7965174581156307
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067138
# Initial rho: 1.7965174581156307
# Final x: 1.7322149244932867
# Final rho: -0.3524079194179388
#
# =========
# Iteration: 47
#
# bwd pass
# Final rho: -0.3524079194179388
# Final cdf: 0.3514966494313362
# Initial cdf: 0.25480536328040626
# Initial rho: -0.6741081259645239
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: -0.6741081259645239
# Final x: -1.8677850755067142
# Final rho: -0.5830335034980925
#
# =========
# Iteration: 48
#
# bwd pass
# Final rho: -0.5830335034980925
# Final cdf: 0.2791012432207356
# Initial cdf: 0.7898964597044908
# Initial rho: 0.867007640187222
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.867007640187222
# Final x: 2.132214924493287
# Final rho: 0.17808226265365285
#
# =========
# Iteration: 49
#
# bwd pass
# Final rho: 0.17808226265365285
# Final cdf: 0.5815632113920827
# Initial cdf: 0.5745563203568826
# Initial rho: 0.16147552193536854
#
# Hamiltonian dynamics
# Initial x: 2.132214924493287
# Initial rho: 0.16147552193536854
# Final x: -1.4677850755067139
# Final rho: -1.187449855598201
#
# =========
# Iteration: 50
#
# bwd pass
# Final rho: -1.187449855598201
# Final cdf: 0.1524990311364977
# Initial cdf: 0.018614568284012645
# Initial rho: -3.290663583200309
#
# Hamiltonian dynamics
# Initial x: -1.4677850755067139
# Initial rho: -3.290663583200309
# Final x: 2.3322149244932873
# Final rho: 1.5104110392661227
#
# =========
# Iteration: 51
#
# bwd pass
# Final rho: 1.5104110392661227
# Final cdf: 0.8895904030283328
# Initial cdf: 0.8111844198892213
# Initial rho: 0.9738373263423333
#
# Hamiltonian dynamics
# Initial x: 2.3322149244932873
# Initial rho: 0.9738373263423333
# Final x: -2.667785075506715
# Final rho: 0.13491194880876298
#
# =========
# Iteration: 52
#
# bwd pass
# Final rho: 0.13491194880876298
# Final cdf: 0.5631035765990371
# Initial cdf: 0.5631180605000333
# Initial rho: 0.13494510115405445
#
# Hamiltonian dynamics
# Initial x: -2.667785075506715
# Initial rho: 0.13494510115405445
# Final x: 2.132214924493287
# Final rho: -1.6939802763795153
#
# =========
# Iteration: 53
#
# bwd pass
# Final rho: -1.6939802763795153
# Final cdf: 0.09189327249364149
# Initial cdf: 0.08488638145844146
# Initial rho: -1.7732944248213687
#
# Hamiltonian dynamics
# Initial x: 2.132214924493287
# Initial rho: -1.7732944248213687
# Final x: -1.467785075506714
# Final rho: 2.897780197645064
#
# =========
# Iteration: 54
#
# bwd pass
# Final rho: 2.897780197645064
# Final cdf: 0.972427251802847
# Initial cdf: 0.8385427889503617
# Initial rho: 1.1303679379252172
#
# Hamiltonian dynamics
# Initial x: -1.467785075506714
# Initial rho: 1.1303679379252172
# Final x: 1.7322149244932867
# Final rho: 0.5614425603916489
#
# =========
# Iteration: 55
#
# bwd pass
# Final rho: 0.5614425603916489
# Final cdf: 0.7148071728351367
# Initial cdf: 0.6181158866842068
# Initial rho: 0.2694909041243468
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.2694909041243468
# Final x: -0.4677850755067139
# Final rho: -1.6094344734092223
#
# =========
# Iteration: 56
#
# bwd pass
# Final rho: -1.6094344734092223
# Final cdf: 0.10000034390307916
# Initial cdf: 0.7572838818740137
# Initial rho: 0.7227155761684425
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067139
# Initial rho: 0.7227155761684425
# Final x: -0.4677850755067138
# Final rho: 0.633790198634872
#
# =========
# Iteration: 57
#
# bwd pass
# Final rho: 0.633790198634872
# Final cdf: 0.7347115035184402
# Initial cdf: 0.3919950414893747
# Initial rho: -0.24335890797353105
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067138
# Initial rho: -0.24335890797353105
# Final x: 0.7322149244932862
# Final rho: 0.18771571449290006
#
# =========
# Iteration: 58
#
# bwd pass
# Final rho: 0.18771571449290006
# Final cdf: 0.5855748480641575
# Initial cdf: 0.6490082259870702
# Initial rho: 0.3538453110915489
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.3538453110915489
# Final x: -0.06778507550671375
# Final rho: 0.544919933557979
#
# =========
# Iteration: 59
#
# bwd pass
# Final rho: 0.544919933557979
# Final cdf: 0.7100558944664999
# Initial cdf: 0.9791665474639715
# Initial rho: 3.178048108634945
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: 3.178048108634945
# Final x: -0.0677850755067137
# Final rho: -3.4108772688986257
#
# =========
# Iteration: 60
#
# bwd pass
# Final rho: -3.4108772688986257
# Final cdf: 0.016506113534486277
# Initial cdf: 0.2856167665319578
# Initial rho: -0.5599571633355225
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.5599571633355225
# Final x: 0.9322149244932864
# Final rho: 0.0011174591309091042
#
# =========
# Iteration: 61
#
# bwd pass
# Final rho: 0.0011174591309091042
# Final cdf: 0.5005584175029771
# Initial cdf: 0.6933710744279781
# Initial rho: 0.488969793407685
#
# Hamiltonian dynamics
# Initial x: 0.9322149244932864
# Initial rho: 0.488969793407685
# Final x: 1.3322149244932866
# Final rho: -0.059955584125883435
#
# =========
# Iteration: 62
#
# bwd pass
# Final rho: -0.059955584125883435
# Final cdf: 0.470903181904088
# Initial cdf: 0.039885846692933935
# Initial rho: -2.5285865569295485
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932866
# Initial rho: -2.5285865569295485
# Final x: -1.0677850755067138
# Final rho: 2.9424880655368844
#
# =========
# Iteration: 63
#
# bwd pass
# Final rho: 2.9424880655368844
# Final cdf: 0.9736328205815867
# Initial cdf: 0.9729879063516612
# Initial rho: 2.9183234197994654
#
# Hamiltonian dynamics
# Initial x: -1.0677850755067138
# Initial rho: 2.9183234197994654
# Final x: 0.7322149244932863
# Final rho: -3.3606019577341057
#
# =========
# Iteration: 64
#
# bwd pass
# Final rho: -3.3606019577341057
# Final cdf: 0.017357178039461352
# Initial cdf: 0.08079055596237406
# Initial rho: -1.8227480213801213
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: -1.8227480213801213
# Final x: -1.6677850755067143
# Final rho: 0.6483266010863106
#
# =========
# Iteration: 65
#
# bwd pass
# Final rho: 0.6483266010863106
# Final cdf: 0.7385399505311967
# Initial cdf: 0.44314678769256344
# Initial rho: -0.12070703406793103
#
# Hamiltonian dynamics
# Initial x: -1.6677850755067143
# Initial rho: -0.12070703406793103
# Final x: 0.13221492449328626
# Final rho: 1.480367588398501
#
# =========
# Iteration: 66
#
# bwd pass
# Final rho: 1.480367588398501
# Final cdf: 0.8862229866060203
# Initial cdf: 0.0008537201065347277
# Initial rho: -6.37275998144013
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: -6.37275998144013
# Final x: 1.932214924493287
# Final rho: 4.228314641026304
#
# =========
# Iteration: 67
#
# bwd pass
# Final rho: 4.228314641026304
# Final cdf: 0.992711531385205
# Initial cdf: 0.9792709604836989
# Initial rho: 3.1830725060772833
#
# Hamiltonian dynamics
# Initial x: 1.932214924493287
# Initial rho: 3.1830725060772833
# Final x: -3.0677850755067153
# Final rho: 0.34414712854371043
#
# =========
# Iteration: 68
#
# bwd pass
# Final rho: 0.34414712854371043
# Final cdf: 0.6455876839793097
# Initial cdf: 0.799974494335488
# Initial rho: 0.91616321168264
#
# Hamiltonian dynamics
# Initial x: -3.0677850755067153
# Initial rho: 0.91616321168264
# Final x: 1.3322149244932866
# Final rho: -4.832762165850931
#
# =========
# Iteration: 69
#
# bwd pass
# Final rho: -4.832762165850931
# Final cdf: 0.003982245804218576
# Initial cdf: 0.5729649105930645
# Initial rho: 0.1577419119728402
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932866
# Initial rho: 0.1577419119728402
# Final x: 0.7322149244932863
# Final rho: -0.8411834655607263
#
# =========
# Iteration: 70
#
# bwd pass
# Final rho: -0.8411834655607263
# Final cdf: 0.21559995554902456
# Initial cdf: 0.27903333347193726
# Initial rho: -0.5832768489275618
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: -0.5832768489275618
# Final x: 0.3322149244932863
# Final rho: -0.89220222646113
#
# =========
# Iteration: 71
#
# bwd pass
# Final rho: -0.89220222646113
# Final cdf: 0.20487619542802438
# Initial cdf: 0.225868343110195
# Initial rho: -0.7946558215093628
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932863
# Initial rho: -0.7946558215093628
# Final x: -0.0677850755067137
# Final rho: -0.9435811990429308
#
# =========
# Iteration: 72
#
# bwd pass
# Final rho: -0.9435811990429308
# Final cdf: 0.19461571061963123
# Initial cdf: 0.46372636361710273
# Initial rho: -0.07531345374101396
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.07531345374101396
# Final x: 0.1322149244932863
# Final rho: -0.07423883127458232
#
# =========
# Iteration: 73
#
# bwd pass
# Final rho: -0.07423883127458232
# Final cdf: 0.4642249622403811
# Initial cdf: 0.5788556957408956
# Initial rho: 0.17163255800941515
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932863
# Initial rho: 0.17163255800941515
# Final x: -0.26778507550671365
# Final rho: 0.18270718047584675
#
# =========
# Iteration: 74
#
# bwd pass
# Final rho: 0.18270718047584675
# Final cdf: 0.5834939788910986
# Initial cdf: 0.04353690248093223
# Initial rho: -2.4409991870635332
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671365
# Initial rho: -2.4409991870635332
# Final x: -0.26778507550671377
# Final rho: 2.470075435402899
#
# =========
# Iteration: 75
#
# bwd pass
# Final rho: 2.470075435402899
# Final cdf: 0.9577107607253471
# Initial cdf: 0.4177536843151809
# Initial rho: -0.1797161115596528
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671377
# Initial rho: -0.1797161115596528
# Final x: 0.1322149244932862
# Final rho: -0.16864148909322169
#
# =========
# Iteration: 76
#
# bwd pass
# Final rho: -0.16864148909322169
# Final cdf: 0.42240586165882515
# Initial cdf: 0.5370365951593397
# Initial rho: 0.07696008668075748
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932862
# Initial rho: 0.07696008668075748
# Final x: -0.06778507550671375
# Final rho: 0.07803470914718857
#
# =========
# Iteration: 77
#
# bwd pass
# Final rho: 0.07803470914718857
# Final cdf: 0.5375338388128642
# Initial cdf: 0.8066444918103358
# Initial rho: 0.9500775925943498
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: 0.9500775925943498
# Final x: 0.33221492449328627
# Final rho: 0.8011522150607799
#
# =========
# Iteration: 78
#
# bwd pass
# Final rho: 0.8011522150607799
# Final cdf: 0.7755942306662682
# Initial cdf: 0.7965863783484388
# Initial rho: 0.89936664727842
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: 0.89936664727842
# Final x: 0.7322149244932862
# Final rho: 0.59044126974485
#
# =========
# Iteration: 79
#
# bwd pass
# Final rho: 0.59044126974485
# Final cdf: 0.7229586345819523
# Initial cdf: 0.786392012504865
# Initial rho: 0.850465597395169
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.850465597395169
# Final x: 1.3322149244932864
# Final rho: -0.14845978013839906
#
# =========
# Iteration: 80
#
# bwd pass
# Final rho: -0.14845978013839906
# Final cdf: 0.4310173386943491
# Initial cdf: 3.4831948436675475e-09
# Initial rho: -18.782168725232907
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: -18.782168725232907
# Final x: 6.132214924493281
# Final rho: 0.3689058972335192
#
# =========
# Iteration: 81
#
# bwd pass
# Final rho: 0.3689058972335192
# Final cdf: 0.6542547607221283
# Initial cdf: 0.9999985161947933
# Initial rho: 12.727753503604013
#
# Hamiltonian dynamics
# Initial x: 6.132214924493281
# Initial rho: 12.727753503604013
# Final x: 1.1322149244932862
# Final rho: 30.888828126070443
#
# =========
# Iteration: 82
#
# bwd pass
# Final rho: 30.888828126070443
# Final cdf: 0.9999999999999807
# Initial cdf: 0.37069006296153983
# Initial rho: -0.2992417947711685
#
# Hamiltonian dynamics
# Initial x: 1.1322149244932862
# Initial rho: -0.2992417947711685
# Final x: 0.932214924493286
# Final rho: -0.3381671723047386
#
# =========
# Iteration: 83
#
# bwd pass
# Final rho: -0.3381671723047386
# Final cdf: 0.35653803568170234
# Initial cdf: 0.5493506926067029
# Initial rho: 0.10391865032698502
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: 0.10391865032698502
# Final x: 0.33221492449328627
# Final rho: 0.6249932727934151
#
# =========
# Iteration: 84
#
# bwd pass
# Final rho: 0.6249932727934151
# Final cdf: 0.7323674853273457
# Initial cdf: 0.7533596330095164
# Initial rho: 0.7066768268852853
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: 0.7066768268852853
# Final x: 0.5322149244932862
# Final rho: 0.7877514493517153
#
# =========
# Iteration: 85
#
# bwd pass
# Final rho: 0.7877514493517153
# Final cdf: 0.7725667817667339
# Initial cdf: 0.7755451510841254
# Initial rho: 0.8009335298817155
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932862
# Initial rho: 0.8009335298817155
# Final x: 0.9322149244932861
# Final rho: 0.4120081523481456
#
# =========
# Iteration: 86
#
# bwd pass
# Final rho: 0.4120081523481456
# Final cdf: 0.6688405617119761
# Initial cdf: 0.861653218636977
# Initial rho: 1.2848446569121876
#
# Hamiltonian dynamics
# Initial x: 0.9322149244932861
# Initial rho: 1.2848446569121876
# Final x: 0.3322149244932861
# Final rho: -1.7140807206213808
#
# =========
# Iteration: 87
#
# bwd pass
# Final rho: -1.7140807206213808
# Final cdf: 0.09006461685757611
# Initial cdf: 0.11105676453974689
# Initial rho: -1.5045666355763392
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932861
# Initial rho: -1.5045666355763392
# Final x: -1.467785075506714
# Final rho: -0.2634920131099074
#
# =========
# Iteration: 88
#
# bwd pass
# Final rho: -0.2634920131099074
# Final cdf: 0.38418187962580885
# Initial cdf: 0.2502974167733236
# Initial rho: -0.6919582205597992
#
# Hamiltonian dynamics
# Initial x: -1.467785075506714
# Initial rho: -0.6919582205597992
# Final x: 0.13221492449328626
# Final rho: 1.5791164019066326
#
# =========
# Iteration: 89
#
# bwd pass
# Final rho: 1.5791164019066326
# Final cdf: 0.8969214110801494
# Initial cdf: 0.011552144580663892
# Initial rho: -3.767737000710854
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: -3.767737000710854
# Final x: 0.33221492449328627
# Final rho: 3.633337621755578
#
# =========
# Iteration: 90
#
# bwd pass
# Final rho: 3.633337621755578
# Final cdf: 0.9867860845289091
# Initial cdf: 0.007778232211079761
# Initial rho: -4.163279008277025
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: -4.163279008277025
# Final x: 0.5322149244932862
# Final rho: 4.237795614189404
#
# =========
# Iteration: 91
#
# bwd pass
# Final rho: 4.237795614189404
# Final cdf: 0.9927803066173007
# Initial cdf: 0.9957586759346921
# Initial rho: 4.769732598373696
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932862
# Initial rho: 4.769732598373696
# Final x: -1.8677850755067142
# Final rho: -3.3791927791598777
#
# =========
# Iteration: 92
#
# bwd pass
# Final rho: -3.3791927791598777
# Final cdf: 0.017037474822676868
# Initial cdf: 0.5278326913064322
# Initial rho: 0.05727470807430557
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.05727470807430557
# Final x: 0.5322149244932864
# Final rho: 1.528349330540738
#
# =========
# Iteration: 93
#
# bwd pass
# Final rho: 1.528349330540738
# Final cdf: 0.8915533043551594
# Initial cdf: 0.8945316736725509
# Initial rho: 1.5561974149668023
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932864
# Initial rho: 1.5561974149668023
# Final x: 0.7322149244932863
# Final rho: -1.5227279625667653
#
# =========
# Iteration: 94
#
# bwd pass
# Final rho: -1.5227279625667653
# Final cdf: 0.10905803108752321
# Initial cdf: 0.17249140901043591
# Initial rho: -1.0642606660290326
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: -1.0642606660290326
# Final x: -0.8677850755067136
# Final rho: -1.0731860435625993
#
# =========
# Iteration: 95
#
# bwd pass
# Final rho: -1.0731860435625993
# Final cdf: 0.17095870820525433
# Initial cdf: 0.12100904755620218
# Initial rho: -1.4187427824290728
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067136
# Initial rho: -1.4187427824290728
# Final x: -0.26778507550671354
# Final rho: 1.9023318400373601
#
# =========
# Iteration: 96
#
# bwd pass
# Final rho: 1.9023318400373601
# Final cdf: 0.9253898722749265
# Initial cdf: 0.3854327958647601
# Initial rho: -0.26024125040911184
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671354
# Initial rho: -0.26024125040911184
# Final x: -0.6677850755067135
# Final rho: -0.02916662794267937
#
# =========
# Iteration: 97
#
# bwd pass
# Final rho: -0.02916662794267937
# Final cdf: 0.4856273064122617
# Initial cdf: 0.3153198464700267
# Initial rho: -0.4610205891327127
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067135
# Initial rho: -0.4610205891327127
# Final x: -0.0677850755067137
# Final rho: -0.5399459666662819
#
# =========
# Iteration: 98
#
# bwd pass
# Final rho: -0.5399459666662819
# Final cdf: 0.2913898705277477
# Initial cdf: 0.5605005235252192
# Initial rho: 0.1289715724813309
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: 0.1289715724813309
# Final x: 0.1322149244932863
# Final rho: -0.14995380505223752
#
# =========
# Iteration: 99
#
# bwd pass
# Final rho: -0.14995380505223752
# Final cdf: 0.4303738688517228
# Initial cdf: 0.5450046023522372
# Initial rho: 0.09432079458226096
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932863
# Initial rho: 0.09432079458226096
# Final x: -0.2677850755067137
# Final rho: -0.05460458295130746
#
# =========

# %%
ttxp=np.linspace(-4,4,1000)
plt.plot(ttxp,np.exp(lp(ttxp[np.newaxis,:])))
plt.hist(xp[0,:],alpha=0.5,density=True,bins=50);

# %%
ttrho=np.linspace(-4,4,1000)
plt.plot(ttrho,np.exp(lap_lm(ttrho[np.newaxis,:])))
plt.hist(rhop[0,:],alpha=0.5,density=True,bins=50);

# %%
plt.hist(up,alpha=0.5,density=True,bins=10);

# %% [markdown]
# ## Backward pass

# %%
xpp,rhopp,upp,lJ,xps,rhops,ups=flow(steps,xp,rhop,up,L,epsilon,grad_lp,lm,Fm,Qm,grad_lm,xi,direction='bwd')
# Out:
# Iteration: 1
#
# bwd pass
# Final rho: -0.27235185303600823
# Final cdf: 0.3807931237542692
# Initial cdf: 0.6499037767517408
# Initial rho: 0.35640005815683623
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671381
# Initial rho: 0.35640005815683623
# Final x: -0.4677850755067138
# Final rho: -0.35252531937673254
#
# =========
# Iteration: 2
#
# bwd pass
# Final rho: -0.35252531937673254
# Final cdf: 0.35145538616137734
# Initial cdf: 0.008738924132311865
# Initial rho: -4.046821013321293
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067138
# Initial rho: -4.046821013321293
# Final x: 1.3322149244932864
# Final rho: 3.5542536091451393
#
# =========
# Iteration: 3
#
# bwd pass
# Final rho: 3.5542536091451393
# Final cdf: 0.9856986421217744
# Initial cdf: 0.5546813069106201
# Initial rho: 0.11581790833339513
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: 0.11581790833339513
# Final x: 0.932214924493286
# Final rho: -0.4331074692001746
#
# =========
# Iteration: 4
#
# bwd pass
# Final rho: -0.4331074692001746
# Final cdf: 0.3242453976364197
# Initial cdf: 0.5170580545614203
# Initial rho: 0.034711647773048686
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: 0.034711647773048686
# Final x: -0.2677850755067139
# Final rho: 0.36578627023947924
#
# =========
# Iteration: 5
#
# bwd pass
# Final rho: 0.36578627023947924
# Final cdf: 0.6531744803808732
# Initial cdf: 0.11321740397070712
# Initial rho: -1.4852981991464425
#
# Hamiltonian dynamics
# Initial x: -0.2677850755067139
# Initial rho: -1.4852981991464425
# Final x: -1.267785075506714
# Final rho: 0.67577642331999
#
# =========
# Iteration: 6
#
# bwd pass
# Final rho: 0.67577642331999
# Final cdf: 0.7456193734412271
# Initial cdf: 0.7154420174098406
# Initial rho: 0.5636710603834536
#
# Hamiltonian dynamics
# Initial x: -1.267785075506714
# Initial rho: 0.5636710603834536
# Final x: 0.5322149244932862
# Final rho: 1.444745682849885
#
# =========
# Iteration: 7
#
# bwd pass
# Final rho: 1.444745682849885
# Final cdf: 0.882096980774725
# Initial cdf: 0.8850753500921165
# Initial rho: 1.4703314030005088
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932862
# Initial rho: 1.4703314030005088
# Final x: 0.932214924493286
# Final rho: -1.0785939745330597
#
# =========
# Iteration: 8
#
# bwd pass
# Final rho: -1.0785939745330597
# Final cdf: 0.17003667071716133
# Initial cdf: 0.36284932764216193
# Initial rho: -0.3206204256909106
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: -0.3206204256909106
# Final x: 0.932214924493286
# Final rho: -0.40954580322448075
#
# =========
# Iteration: 9
#
# bwd pass
# Final rho: -0.40954580322448075
# Final cdf: 0.33197587320206856
# Initial cdf: 0.5247885301270692
# Initial rho: 0.05084819372706201
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: 0.05084819372706201
# Final x: -0.2677850755067139
# Final rho: 0.3819228161934924
#
# =========
# Iteration: 10
#
# bwd pass
# Final rho: 0.3819228161934924
# Final cdf: 0.6587261335977506
# Initial cdf: 0.11876905718758446
# Initial rho: -1.4374271868035737
#
# Hamiltonian dynamics
# Initial x: -0.2677850755067139
# Initial rho: -1.4374271868035737
# Final x: -1.267785075506714
# Final rho: 0.7236474356628587
#
# =========
# Iteration: 11
#
# bwd pass
# Final rho: 0.7236474356628587
# Final cdf: 0.7575099538431225
# Initial cdf: 0.727332597811736
# Initial rho: 0.6063553529792219
#
# Hamiltonian dynamics
# Initial x: -1.267785075506714
# Initial rho: 0.6063553529792219
# Final x: 0.33221492449328627
# Final rho: 1.2374299754456541
#
# =========
# Iteration: 12
#
# bwd pass
# Final rho: 1.2374299754456541
# Final cdf: 0.8549355505003937
# Initial cdf: 0.8759276981825643
# Initial rho: 1.3937436235688976
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: 1.3937436235688976
# Final x: 1.3322149244932864
# Final rho: -0.4451817539646703
#
# =========
# Iteration: 13
#
# bwd pass
# Final rho: -0.4451817539646703
# Final cdf: 0.3203539071317538
# Initial cdf: 0.8893365719205996
# Initial rho: 1.5081146829447893
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: 1.5081146829447893
# Final x: -0.6677850755067136
# Final rho: -2.0808106945887808
#
# =========
# Iteration: 14
#
# bwd pass
# Final rho: -2.0808106945887808
# Final cdf: 0.06241448649708009
# Initial cdf: 0.8921070265548452
# Initial rho: 1.5334683492687908
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067136
# Initial rho: 1.5334683492687908
# Final x: 1.732214924493287
# Final rho: 0.1245429717352231
#
# =========
# Iteration: 15
#
# bwd pass
# Final rho: 0.1245429717352231
# Final cdf: 0.5585498396038028
# Initial cdf: 0.46185855345287286
# Initial rho: -0.07934941557482753
#
# Hamiltonian dynamics
# Initial x: 1.732214924493287
# Initial rho: -0.07934941557482753
# Final x: -0.0677850755067137
# Final rho: -1.3582747931083945
#
# =========
# Iteration: 16
#
# bwd pass
# Final rho: -1.3582747931083945
# Final cdf: 0.12855197603461144
# Initial cdf: 0.39766262903208294
# Initial rho: -0.22900411835805562
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.22900411835805562
# Final x: 0.3322149244932864
# Final rho: 0.04207050410837601
#
# =========
# Iteration: 17
#
# bwd pass
# Final rho: 0.04207050410837601
# Final cdf: 0.5205989106516552
# Initial cdf: 0.5415910583338258
# Initial rho: 0.08684642695934491
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932864
# Initial rho: 0.08684642695934491
# Final x: 0.3322149244932864
# Final rho: 0.11792104942577658
#
# =========
# Iteration: 18
#
# bwd pass
# Final rho: 0.11792104942577658
# Final cdf: 0.5556168907759693
# Initial cdf: 0.5766090384581399
# Initial rho: 0.16631208727602018
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932864
# Initial rho: 0.16631208727602018
# Final x: 0.13221492449328637
# Final rho: 0.12738670974245186
#
# =========
# Iteration: 19
#
# bwd pass
# Final rho: 0.12738670974245186
# Final cdf: 0.5598034249243122
# Initial cdf: 0.6744341584248266
# Initial rho: 0.4290433789643159
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328637
# Initial rho: 0.4290433789643159
# Final x: -0.8677850755067135
# Final rho: 0.19011800143074709
#
# =========
# Iteration: 20
#
# bwd pass
# Final rho: 0.19011800143074709
# Final cdf: 0.5865692213302048
# Initial cdf: 0.5366195606811526
# Initial rho: 0.0760596985387289
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067135
# Initial rho: 0.0760596985387289
# Final x: -0.2677850755067137
# Final rho: -0.5228656789948398
#
# =========
# Iteration: 21
#
# bwd pass
# Final rho: -0.5228656789948398
# Final cdf: 0.29640964086479504
# Initial cdf: 0.7564525644546287
# Initial rho: 0.7192963677041504
#
# Hamiltonian dynamics
# Initial x: -0.2677850755067137
# Initial rho: 0.7192963677041504
# Final x: -0.06778507550671353
# Final rho: 0.9203709901705814
#
# =========
# Iteration: 22
#
# bwd pass
# Final rho: 0.9203709901705814
# Final cdf: 0.8008143890705413
# Initial cdf: 0.06992504206801264
# Initial rho: -1.9671842577181513
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671353
# Initial rho: -1.9671842577181513
# Final x: -0.8677850755067137
# Final rho: 1.7838903647482809
#
# =========
# Iteration: 23
#
# bwd pass
# Final rho: 1.7838903647482809
# Final cdf: 0.9160083210620593
# Initial cdf: 0.8660586604130072
# Initial rho: 1.3172061585942072
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067137
# Initial rho: 1.3172061585942072
# Final x: 1.7322149244932867
# Final rho: 0.43828078106063845
#
# =========
# Iteration: 24
#
# bwd pass
# Final rho: 0.43828078106063845
# Final cdf: 0.6774276934823779
# Initial cdf: 0.5807364073314479
# Initial rho: 0.17610827685254027
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.17610827685254027
# Final x: -0.4677850755067139
# Final rho: -1.7028171006810284
#
# =========
# Iteration: 25
#
# bwd pass
# Final rho: -1.7028171006810284
# Final cdf: 0.09108480519292705
# Initial cdf: 0.7483683431638617
# Initial rho: 0.6866417594276201
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067139
# Initial rho: 0.6866417594276201
# Final x: -0.4677850755067138
# Final rho: 0.5977163818940496
#
# =========
# Iteration: 26
#
# bwd pass
# Final rho: 0.5977163818940496
# Final cdf: 0.7249668278125125
# Initial cdf: 0.38225036578344707
# Initial rho: -0.268532296691445
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067138
# Initial rho: -0.268532296691445
# Final x: 0.13221492449328626
# Final rho: 0.2525423257749861
#
# =========
# Iteration: 27
#
# bwd pass
# Final rho: 0.2525423257749861
# Final cdf: 0.6115883337530499
# Initial cdf: 0.7262190672535643
# Initial rho: 0.6022798273410744
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: 0.6022798273410744
# Final x: -0.6677850755067137
# Final rho: 0.3133544498075045
#
# =========
# Iteration: 28
#
# bwd pass
# Final rho: 0.3133544498075045
# Final cdf: 0.6345046164460616
# Initial cdf: 0.46419715650382676
# Initial rho: -0.07429873018478984
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067137
# Initial rho: -0.07429873018478984
# Final x: -0.26778507550671377
# Final rho: 0.1567758922816413
#
# =========
# Iteration: 29
#
# bwd pass
# Final rho: 0.1567758922816413
# Final cdf: 0.5725521869703872
# Initial cdf: 0.03259511056022102
# Initial rho: -2.730445804113383
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671377
# Initial rho: -2.730445804113383
# Final x: -0.06778507550671375
# Final rho: 2.6706288183530495
#
# =========
# Iteration: 30
#
# bwd pass
# Final rho: 2.6706288183530495
# Final cdf: 0.9653956540360944
# Initial cdf: 0.234506307033566
# Initial rho: -0.7571256152320129
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: -0.7571256152320129
# Final x: -0.06778507550671392
# Final rho: -0.846050992765583
#
# =========
# Iteration: 31
#
# bwd pass
# Final rho: -0.846050992765583
# Final cdf: 0.21455306684662157
# Initial cdf: 0.4836637198440933
# Initial rho: -0.03321822689712067
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671392
# Initial rho: -0.03321822689712067
# Final x: -0.06778507550671392
# Final rho: -0.002143604430690241
#
# =========
# Iteration: 32
#
# bwd pass
# Final rho: -0.002143604430690241
# Final cdf: 0.4989293457242544
# Initial cdf: 0.7680399987217261
# Initial rho: 0.7680431499032006
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671392
# Initial rho: 0.7680431499032006
# Final x: 0.13221492449328626
# Final rho: 0.9291177723696302
#
# =========
# Iteration: 33
#
# bwd pass
# Final rho: 0.9291177723696302
# Final cdf: 0.8025490249263275
# Initial cdf: 0.917179758426842
# Initial rho: 1.7979356034633587
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: 1.7979356034633587
# Final x: 1.1322149244932862
# Final rho: -1.0409897740702108
#
# =========
# Iteration: 34
#
# bwd pass
# Final rho: -1.0409897740702108
# Final cdf: 0.17655250737694755
# Initial cdf: 0.5472425703385067
# Initial rho: 0.09925159171823085
#
# Hamiltonian dynamics
# Initial x: 1.1322149244932862
# Initial rho: 0.09925159171823085
# Final x: 0.7322149244932862
# Final rho: 0.3903262141846606
#
# =========
# Iteration: 35
#
# bwd pass
# Final rho: 0.3903262141846606
# Final cdf: 0.6615819775186484
# Initial cdf: 0.7250153554415611
# Initial rho: 0.5978928402839312
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.5978928402839312
# Final x: 0.7322149244932862
# Final rho: 0.5089674627503611
#
# =========
# Iteration: 36
#
# bwd pass
# Final rho: 0.5089674627503611
# Final cdf: 0.6994420334600187
# Initial cdf: 0.7628754113829314
# Initial rho: 0.7460224050464577
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.7460224050464577
# Final x: 1.3322149244932864
# Final rho: -0.2529029724871108
#
# =========
# Iteration: 37
#
# bwd pass
# Final rho: -0.2529029724871108
# Final cdf: 0.38827161211311667
# Initial cdf: 0.9572542769019624
# Initial rho: 2.459338952534555
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: 2.459338952534555
# Final x: -1.4677850755067139
# Final rho: -2.169586424999016
#
# =========
# Iteration: 38
#
# bwd pass
# Final rho: -2.169586424999016
# Final cdf: 0.057112423842461624
# Initial cdf: 0.9232279609899765
# Initial rho: 1.8737675999504197
#
# Hamiltonian dynamics
# Initial x: -1.4677850755067139
# Initial rho: 1.8737675999504197
# Final x: 1.5322149244932868
# Final rho: -1.9651577775831504
#
# =========
# Iteration: 39
#
# bwd pass
# Final rho: -1.9651577775831504
# Final cdf: 0.07006688745158651
# Initial cdf: 0.8264513080887917
# Initial rho: 1.058149893387352
#
# Hamiltonian dynamics
# Initial x: 1.5322149244932868
# Initial rho: 1.058149893387352
# Final x: -0.6677850755067136
# Final rho: -1.820775484146217
#
# =========
# Iteration: 40
#
# bwd pass
# Final rho: -1.820775484146217
# Final cdf: 0.0809500756196665
# Initial cdf: 0.9106426156774317
# Initial rho: 1.7219642153232255
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067136
# Initial rho: 1.7219642153232255
# Final x: 1.732214924493287
# Final rho: -0.4269611622103431
#
# =========
# Iteration: 41
#
# bwd pass
# Final rho: -0.4269611622103431
# Final cdf: 0.3262444464810933
# Initial cdf: 0.22955316033016337
# Initial rho: -0.7784734603193866
#
# Hamiltonian dynamics
# Initial x: 1.732214924493287
# Initial rho: -0.7784734603193866
# Final x: -1.8677850755067142
# Final rho: -0.687398837852955
#
# =========
# Iteration: 42
#
# bwd pass
# Final rho: -0.687398837852955
# Final cdf: 0.2514412240329956
# Initial cdf: 0.7622364405167509
# Initial rho: 0.7433313660961746
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.7433313660961746
# Final x: 2.3322149244932873
# Final rho: 0.06440598856260601
#
# =========
# Iteration: 43
#
# bwd pass
# Final rho: 0.06440598856260601
# Final cdf: 0.5311878712385336
# Initial cdf: 0.45278188809942216
# Initial rho: -0.0991975721136592
#
# Hamiltonian dynamics
# Initial x: 2.3322149244932873
# Initial rho: -0.0991975721136592
# Final x: -1.8677850755067142
# Final rho: -0.7781229496472282
#
# =========
# Iteration: 44
#
# bwd pass
# Final rho: -0.7781229496472282
# Final cdf: 0.22963363526552472
# Initial cdf: 0.74042885174928
# Initial rho: 0.6555772590186038
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.6555772590186038
# Final x: 1.7322149244932867
# Final rho: 0.7466518814850355
#
# =========
# Iteration: 45
#
# bwd pass
# Final rho: 0.7466518814850355
# Final cdf: 0.7630246287551361
# Initial cdf: 0.6663333426042062
# Initial rho: 0.40446563555991494
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.40446563555991494
# Final x: -0.6677850755067138
# Final rho: -1.7444597419736545
#
# =========
# Iteration: 46
#
# bwd pass
# Final rho: -1.7444597419736545
# Final cdf: 0.08736968390801553
# Initial cdf: 0.9170622239657809
# Initial rho: 1.7965174581156307
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067138
# Initial rho: 1.7965174581156307
# Final x: 1.7322149244932867
# Final rho: -0.3524079194179388
#
# =========
# Iteration: 47
#
# bwd pass
# Final rho: -0.3524079194179388
# Final cdf: 0.3514966494313362
# Initial cdf: 0.25480536328040626
# Initial rho: -0.6741081259645239
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: -0.6741081259645239
# Final x: -1.8677850755067142
# Final rho: -0.5830335034980925
#
# =========
# Iteration: 48
#
# bwd pass
# Final rho: -0.5830335034980925
# Final cdf: 0.2791012432207356
# Initial cdf: 0.7898964597044908
# Initial rho: 0.867007640187222
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.867007640187222
# Final x: 2.132214924493287
# Final rho: 0.17808226265365285
#
# =========
# Iteration: 49
#
# bwd pass
# Final rho: 0.17808226265365285
# Final cdf: 0.5815632113920827
# Initial cdf: 0.5745563203568826
# Initial rho: 0.16147552193536854
#
# Hamiltonian dynamics
# Initial x: 2.132214924493287
# Initial rho: 0.16147552193536854
# Final x: -1.4677850755067139
# Final rho: -1.187449855598201
#
# =========
# Iteration: 50
#
# bwd pass
# Final rho: -1.187449855598201
# Final cdf: 0.1524990311364977
# Initial cdf: 0.018614568284012645
# Initial rho: -3.290663583200309
#
# Hamiltonian dynamics
# Initial x: -1.4677850755067139
# Initial rho: -3.290663583200309
# Final x: 2.3322149244932873
# Final rho: 1.5104110392661227
#
# =========
# Iteration: 51
#
# bwd pass
# Final rho: 1.5104110392661227
# Final cdf: 0.8895904030283328
# Initial cdf: 0.8111844198892213
# Initial rho: 0.9738373263423333
#
# Hamiltonian dynamics
# Initial x: 2.3322149244932873
# Initial rho: 0.9738373263423333
# Final x: -2.667785075506715
# Final rho: 0.13491194880876298
#
# =========
# Iteration: 52
#
# bwd pass
# Final rho: 0.13491194880876298
# Final cdf: 0.5631035765990371
# Initial cdf: 0.5631180605000333
# Initial rho: 0.13494510115405445
#
# Hamiltonian dynamics
# Initial x: -2.667785075506715
# Initial rho: 0.13494510115405445
# Final x: 2.132214924493287
# Final rho: -1.6939802763795153
#
# =========
# Iteration: 53
#
# bwd pass
# Final rho: -1.6939802763795153
# Final cdf: 0.09189327249364149
# Initial cdf: 0.08488638145844146
# Initial rho: -1.7732944248213687
#
# Hamiltonian dynamics
# Initial x: 2.132214924493287
# Initial rho: -1.7732944248213687
# Final x: -1.467785075506714
# Final rho: 2.897780197645064
#
# =========
# Iteration: 54
#
# bwd pass
# Final rho: 2.897780197645064
# Final cdf: 0.972427251802847
# Initial cdf: 0.8385427889503617
# Initial rho: 1.1303679379252172
#
# Hamiltonian dynamics
# Initial x: -1.467785075506714
# Initial rho: 1.1303679379252172
# Final x: 1.7322149244932867
# Final rho: 0.5614425603916489
#
# =========
# Iteration: 55
#
# bwd pass
# Final rho: 0.5614425603916489
# Final cdf: 0.7148071728351367
# Initial cdf: 0.6181158866842068
# Initial rho: 0.2694909041243468
#
# Hamiltonian dynamics
# Initial x: 1.7322149244932867
# Initial rho: 0.2694909041243468
# Final x: -0.4677850755067139
# Final rho: -1.6094344734092223
#
# =========
# Iteration: 56
#
# bwd pass
# Final rho: -1.6094344734092223
# Final cdf: 0.10000034390307916
# Initial cdf: 0.7572838818740137
# Initial rho: 0.7227155761684425
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067139
# Initial rho: 0.7227155761684425
# Final x: -0.4677850755067138
# Final rho: 0.633790198634872
#
# =========
# Iteration: 57
#
# bwd pass
# Final rho: 0.633790198634872
# Final cdf: 0.7347115035184402
# Initial cdf: 0.3919950414893747
# Initial rho: -0.24335890797353105
#
# Hamiltonian dynamics
# Initial x: -0.4677850755067138
# Initial rho: -0.24335890797353105
# Final x: 0.7322149244932862
# Final rho: 0.18771571449290006
#
# =========
# Iteration: 58
#
# bwd pass
# Final rho: 0.18771571449290006
# Final cdf: 0.5855748480641575
# Initial cdf: 0.6490082259870702
# Initial rho: 0.3538453110915489
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.3538453110915489
# Final x: -0.06778507550671375
# Final rho: 0.544919933557979
#
# =========
# Iteration: 59
#
# bwd pass
# Final rho: 0.544919933557979
# Final cdf: 0.7100558944664999
# Initial cdf: 0.9791665474639715
# Initial rho: 3.178048108634945
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: 3.178048108634945
# Final x: -0.0677850755067137
# Final rho: -3.4108772688986257
#
# =========
# Iteration: 60
#
# bwd pass
# Final rho: -3.4108772688986257
# Final cdf: 0.016506113534486277
# Initial cdf: 0.2856167665319578
# Initial rho: -0.5599571633355225
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.5599571633355225
# Final x: 0.9322149244932864
# Final rho: 0.0011174591309091042
#
# =========
# Iteration: 61
#
# bwd pass
# Final rho: 0.0011174591309091042
# Final cdf: 0.5005584175029771
# Initial cdf: 0.6933710744279781
# Initial rho: 0.488969793407685
#
# Hamiltonian dynamics
# Initial x: 0.9322149244932864
# Initial rho: 0.488969793407685
# Final x: 1.3322149244932866
# Final rho: -0.059955584125883435
#
# =========
# Iteration: 62
#
# bwd pass
# Final rho: -0.059955584125883435
# Final cdf: 0.470903181904088
# Initial cdf: 0.039885846692933935
# Initial rho: -2.5285865569295485
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932866
# Initial rho: -2.5285865569295485
# Final x: -1.0677850755067138
# Final rho: 2.9424880655368844
#
# =========
# Iteration: 63
#
# bwd pass
# Final rho: 2.9424880655368844
# Final cdf: 0.9736328205815867
# Initial cdf: 0.9729879063516612
# Initial rho: 2.9183234197994654
#
# Hamiltonian dynamics
# Initial x: -1.0677850755067138
# Initial rho: 2.9183234197994654
# Final x: 0.7322149244932863
# Final rho: -3.3606019577341057
#
# =========
# Iteration: 64
#
# bwd pass
# Final rho: -3.3606019577341057
# Final cdf: 0.017357178039461352
# Initial cdf: 0.08079055596237406
# Initial rho: -1.8227480213801213
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: -1.8227480213801213
# Final x: -1.6677850755067143
# Final rho: 0.6483266010863106
#
# =========
# Iteration: 65
#
# bwd pass
# Final rho: 0.6483266010863106
# Final cdf: 0.7385399505311967
# Initial cdf: 0.44314678769256344
# Initial rho: -0.12070703406793103
#
# Hamiltonian dynamics
# Initial x: -1.6677850755067143
# Initial rho: -0.12070703406793103
# Final x: 0.13221492449328626
# Final rho: 1.480367588398501
#
# =========
# Iteration: 66
#
# bwd pass
# Final rho: 1.480367588398501
# Final cdf: 0.8862229866060203
# Initial cdf: 0.0008537201065347277
# Initial rho: -6.37275998144013
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: -6.37275998144013
# Final x: 1.932214924493287
# Final rho: 4.228314641026304
#
# =========
# Iteration: 67
#
# bwd pass
# Final rho: 4.228314641026304
# Final cdf: 0.992711531385205
# Initial cdf: 0.9792709604836989
# Initial rho: 3.1830725060772833
#
# Hamiltonian dynamics
# Initial x: 1.932214924493287
# Initial rho: 3.1830725060772833
# Final x: -3.0677850755067153
# Final rho: 0.34414712854371043
#
# =========
# Iteration: 68
#
# bwd pass
# Final rho: 0.34414712854371043
# Final cdf: 0.6455876839793097
# Initial cdf: 0.799974494335488
# Initial rho: 0.91616321168264
#
# Hamiltonian dynamics
# Initial x: -3.0677850755067153
# Initial rho: 0.91616321168264
# Final x: 1.3322149244932866
# Final rho: -4.832762165850931
#
# =========
# Iteration: 69
#
# bwd pass
# Final rho: -4.832762165850931
# Final cdf: 0.003982245804218576
# Initial cdf: 0.5729649105930645
# Initial rho: 0.1577419119728402
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932866
# Initial rho: 0.1577419119728402
# Final x: 0.7322149244932863
# Final rho: -0.8411834655607263
#
# =========
# Iteration: 70
#
# bwd pass
# Final rho: -0.8411834655607263
# Final cdf: 0.21559995554902456
# Initial cdf: 0.27903333347193726
# Initial rho: -0.5832768489275618
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: -0.5832768489275618
# Final x: 0.3322149244932863
# Final rho: -0.89220222646113
#
# =========
# Iteration: 71
#
# bwd pass
# Final rho: -0.89220222646113
# Final cdf: 0.20487619542802438
# Initial cdf: 0.225868343110195
# Initial rho: -0.7946558215093628
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932863
# Initial rho: -0.7946558215093628
# Final x: -0.0677850755067137
# Final rho: -0.9435811990429308
#
# =========
# Iteration: 72
#
# bwd pass
# Final rho: -0.9435811990429308
# Final cdf: 0.19461571061963123
# Initial cdf: 0.46372636361710273
# Initial rho: -0.07531345374101396
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: -0.07531345374101396
# Final x: 0.1322149244932863
# Final rho: -0.07423883127458232
#
# =========
# Iteration: 73
#
# bwd pass
# Final rho: -0.07423883127458232
# Final cdf: 0.4642249622403811
# Initial cdf: 0.5788556957408956
# Initial rho: 0.17163255800941515
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932863
# Initial rho: 0.17163255800941515
# Final x: -0.26778507550671365
# Final rho: 0.18270718047584675
#
# =========
# Iteration: 74
#
# bwd pass
# Final rho: 0.18270718047584675
# Final cdf: 0.5834939788910986
# Initial cdf: 0.04353690248093223
# Initial rho: -2.4409991870635332
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671365
# Initial rho: -2.4409991870635332
# Final x: -0.26778507550671377
# Final rho: 2.470075435402899
#
# =========
# Iteration: 75
#
# bwd pass
# Final rho: 2.470075435402899
# Final cdf: 0.9577107607253471
# Initial cdf: 0.4177536843151809
# Initial rho: -0.1797161115596528
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671377
# Initial rho: -0.1797161115596528
# Final x: 0.1322149244932862
# Final rho: -0.16864148909322169
#
# =========
# Iteration: 76
#
# bwd pass
# Final rho: -0.16864148909322169
# Final cdf: 0.42240586165882515
# Initial cdf: 0.5370365951593397
# Initial rho: 0.07696008668075748
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932862
# Initial rho: 0.07696008668075748
# Final x: -0.06778507550671375
# Final rho: 0.07803470914718857
#
# =========
# Iteration: 77
#
# bwd pass
# Final rho: 0.07803470914718857
# Final cdf: 0.5375338388128642
# Initial cdf: 0.8066444918103358
# Initial rho: 0.9500775925943498
#
# Hamiltonian dynamics
# Initial x: -0.06778507550671375
# Initial rho: 0.9500775925943498
# Final x: 0.33221492449328627
# Final rho: 0.8011522150607799
#
# =========
# Iteration: 78
#
# bwd pass
# Final rho: 0.8011522150607799
# Final cdf: 0.7755942306662682
# Initial cdf: 0.7965863783484388
# Initial rho: 0.89936664727842
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: 0.89936664727842
# Final x: 0.7322149244932862
# Final rho: 0.59044126974485
#
# =========
# Iteration: 79
#
# bwd pass
# Final rho: 0.59044126974485
# Final cdf: 0.7229586345819523
# Initial cdf: 0.786392012504865
# Initial rho: 0.850465597395169
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932862
# Initial rho: 0.850465597395169
# Final x: 1.3322149244932864
# Final rho: -0.14845978013839906
#
# =========
# Iteration: 80
#
# bwd pass
# Final rho: -0.14845978013839906
# Final cdf: 0.4310173386943491
# Initial cdf: 3.4831948436675475e-09
# Initial rho: -18.782168725232907
#
# Hamiltonian dynamics
# Initial x: 1.3322149244932864
# Initial rho: -18.782168725232907
# Final x: 6.132214924493281
# Final rho: 0.3689058972335192
#
# =========
# Iteration: 81
#
# bwd pass
# Final rho: 0.3689058972335192
# Final cdf: 0.6542547607221283
# Initial cdf: 0.9999985161947933
# Initial rho: 12.727753503604013
#
# Hamiltonian dynamics
# Initial x: 6.132214924493281
# Initial rho: 12.727753503604013
# Final x: 1.1322149244932862
# Final rho: 30.888828126070443
#
# =========
# Iteration: 82
#
# bwd pass
# Final rho: 30.888828126070443
# Final cdf: 0.9999999999999807
# Initial cdf: 0.37069006296153983
# Initial rho: -0.2992417947711685
#
# Hamiltonian dynamics
# Initial x: 1.1322149244932862
# Initial rho: -0.2992417947711685
# Final x: 0.932214924493286
# Final rho: -0.3381671723047386
#
# =========
# Iteration: 83
#
# bwd pass
# Final rho: -0.3381671723047386
# Final cdf: 0.35653803568170234
# Initial cdf: 0.5493506926067029
# Initial rho: 0.10391865032698502
#
# Hamiltonian dynamics
# Initial x: 0.932214924493286
# Initial rho: 0.10391865032698502
# Final x: 0.33221492449328627
# Final rho: 0.6249932727934151
#
# =========
# Iteration: 84
#
# bwd pass
# Final rho: 0.6249932727934151
# Final cdf: 0.7323674853273457
# Initial cdf: 0.7533596330095164
# Initial rho: 0.7066768268852853
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: 0.7066768268852853
# Final x: 0.5322149244932862
# Final rho: 0.7877514493517153
#
# =========
# Iteration: 85
#
# bwd pass
# Final rho: 0.7877514493517153
# Final cdf: 0.7725667817667339
# Initial cdf: 0.7755451510841254
# Initial rho: 0.8009335298817155
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932862
# Initial rho: 0.8009335298817155
# Final x: 0.9322149244932861
# Final rho: 0.4120081523481456
#
# =========
# Iteration: 86
#
# bwd pass
# Final rho: 0.4120081523481456
# Final cdf: 0.6688405617119761
# Initial cdf: 0.861653218636977
# Initial rho: 1.2848446569121876
#
# Hamiltonian dynamics
# Initial x: 0.9322149244932861
# Initial rho: 1.2848446569121876
# Final x: 0.3322149244932861
# Final rho: -1.7140807206213808
#
# =========
# Iteration: 87
#
# bwd pass
# Final rho: -1.7140807206213808
# Final cdf: 0.09006461685757611
# Initial cdf: 0.11105676453974689
# Initial rho: -1.5045666355763392
#
# Hamiltonian dynamics
# Initial x: 0.3322149244932861
# Initial rho: -1.5045666355763392
# Final x: -1.467785075506714
# Final rho: -0.2634920131099074
#
# =========
# Iteration: 88
#
# bwd pass
# Final rho: -0.2634920131099074
# Final cdf: 0.38418187962580885
# Initial cdf: 0.2502974167733236
# Initial rho: -0.6919582205597992
#
# Hamiltonian dynamics
# Initial x: -1.467785075506714
# Initial rho: -0.6919582205597992
# Final x: 0.13221492449328626
# Final rho: 1.5791164019066326
#
# =========
# Iteration: 89
#
# bwd pass
# Final rho: 1.5791164019066326
# Final cdf: 0.8969214110801494
# Initial cdf: 0.011552144580663892
# Initial rho: -3.767737000710854
#
# Hamiltonian dynamics
# Initial x: 0.13221492449328626
# Initial rho: -3.767737000710854
# Final x: 0.33221492449328627
# Final rho: 3.633337621755578
#
# =========
# Iteration: 90
#
# bwd pass
# Final rho: 3.633337621755578
# Final cdf: 0.9867860845289091
# Initial cdf: 0.007778232211079761
# Initial rho: -4.163279008277025
#
# Hamiltonian dynamics
# Initial x: 0.33221492449328627
# Initial rho: -4.163279008277025
# Final x: 0.5322149244932862
# Final rho: 4.237795614189404
#
# =========
# Iteration: 91
#
# bwd pass
# Final rho: 4.237795614189404
# Final cdf: 0.9927803066173007
# Initial cdf: 0.9957586759346921
# Initial rho: 4.769732598373696
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932862
# Initial rho: 4.769732598373696
# Final x: -1.8677850755067142
# Final rho: -3.3791927791598777
#
# =========
# Iteration: 92
#
# bwd pass
# Final rho: -3.3791927791598777
# Final cdf: 0.017037474822676868
# Initial cdf: 0.5278326913064322
# Initial rho: 0.05727470807430557
#
# Hamiltonian dynamics
# Initial x: -1.8677850755067142
# Initial rho: 0.05727470807430557
# Final x: 0.5322149244932864
# Final rho: 1.528349330540738
#
# =========
# Iteration: 93
#
# bwd pass
# Final rho: 1.528349330540738
# Final cdf: 0.8915533043551594
# Initial cdf: 0.8945316736725509
# Initial rho: 1.5561974149668023
#
# Hamiltonian dynamics
# Initial x: 0.5322149244932864
# Initial rho: 1.5561974149668023
# Final x: 0.7322149244932863
# Final rho: -1.5227279625667653
#
# =========
# Iteration: 94
#
# bwd pass
# Final rho: -1.5227279625667653
# Final cdf: 0.10905803108752321
# Initial cdf: 0.17249140901043591
# Initial rho: -1.0642606660290326
#
# Hamiltonian dynamics
# Initial x: 0.7322149244932863
# Initial rho: -1.0642606660290326
# Final x: -0.8677850755067136
# Final rho: -1.0731860435625993
#
# =========
# Iteration: 95
#
# bwd pass
# Final rho: -1.0731860435625993
# Final cdf: 0.17095870820525433
# Initial cdf: 0.12100904755620218
# Initial rho: -1.4187427824290728
#
# Hamiltonian dynamics
# Initial x: -0.8677850755067136
# Initial rho: -1.4187427824290728
# Final x: -0.26778507550671354
# Final rho: 1.9023318400373601
#
# =========
# Iteration: 96
#
# bwd pass
# Final rho: 1.9023318400373601
# Final cdf: 0.9253898722749265
# Initial cdf: 0.3854327958647601
# Initial rho: -0.26024125040911184
#
# Hamiltonian dynamics
# Initial x: -0.26778507550671354
# Initial rho: -0.26024125040911184
# Final x: -0.6677850755067135
# Final rho: -0.02916662794267937
#
# =========
# Iteration: 97
#
# bwd pass
# Final rho: -0.02916662794267937
# Final cdf: 0.4856273064122617
# Initial cdf: 0.3153198464700267
# Initial rho: -0.4610205891327127
#
# Hamiltonian dynamics
# Initial x: -0.6677850755067135
# Initial rho: -0.4610205891327127
# Final x: -0.0677850755067137
# Final rho: -0.5399459666662819
#
# =========
# Iteration: 98
#
# bwd pass
# Final rho: -0.5399459666662819
# Final cdf: 0.2913898705277477
# Initial cdf: 0.5605005235252192
# Initial rho: 0.1289715724813309
#
# Hamiltonian dynamics
# Initial x: -0.0677850755067137
# Initial rho: 0.1289715724813309
# Final x: 0.1322149244932863
# Final rho: -0.14995380505223752
#
# =========
# Iteration: 99
#
# bwd pass
# Final rho: -0.14995380505223752
# Final cdf: 0.4303738688517228
# Initial cdf: 0.5450046023522372
# Initial rho: 0.09432079458226096
#
# Hamiltonian dynamics
# Initial x: 0.1322149244932863
# Initial rho: 0.09432079458226096
# Final x: -0.2677850755067137
# Final rho: -0.05460458295130746
#
# =========

# %%
ttx=np.linspace(mu0-4*sigma0,mu0+4*sigma0,1000)
plt.plot(ttx,np.exp(lq0(ttx[np.newaxis,:])))
plt.hist(xpp[0,:],alpha=0.5,density=True,bins=50);

# %%
plt.plot(ttrho,np.exp(lap_lm(ttrho[np.newaxis,:])))
plt.hist(rhopp[0,:],alpha=0.5,density=True,bins=50);

# %%
plt.hist(upp,alpha=0.5,density=True,bins=10);

# %%
plt.plot(np.arange(0,steps),np.flip(xs[:,0,0]))
plt.plot(np.arange(0,steps),xps[:,0,0])

# %%
plt.plot(np.arange(0,steps),np.flip(rhos[:,0,0]))
plt.plot(np.arange(0,steps),rhops[:,0,0])

# %%
plt.plot(np.arange(0,steps),np.flip(us[:,0]))
plt.plot(np.arange(0,steps),ups[:,0])

# %%
np.flip(xs[:,0,0])
# Out:
# array([-6.77850755e-02, -4.67785076e-01,  1.33221492e+00,  9.32214924e-01,
#        -2.67785076e-01, -1.26778508e+00,  5.32214924e-01,  9.32214924e-01,
#         9.32214924e-01, -2.67785076e-01, -1.26778508e+00,  3.32214924e-01,
#         1.33221492e+00, -6.67785076e-01,  1.73221492e+00, -6.77850755e-02,
#         3.32214924e-01,  3.32214924e-01,  1.32214924e-01, -8.67785076e-01,
#        -2.67785076e-01, -6.77850755e-02, -8.67785076e-01,  1.73221492e+00,
#        -4.67785076e-01, -4.67785076e-01,  1.32214924e-01, -6.67785076e-01,
#        -2.67785076e-01, -6.77850755e-02, -6.77850755e-02, -6.77850755e-02,
#         1.32214924e-01,  1.13221492e+00,  7.32214924e-01,  7.32214924e-01,
#         1.33221492e+00, -1.46778508e+00,  1.53221492e+00, -6.67785076e-01,
#         1.73221492e+00, -1.86778508e+00,  2.33221492e+00, -1.86778508e+00,
#         1.73221492e+00, -6.67785076e-01,  1.73221492e+00, -1.86778508e+00,
#         2.13221492e+00, -1.46778508e+00,  2.33221492e+00, -2.66778508e+00,
#         2.13221492e+00, -1.46778508e+00,  1.73221492e+00, -4.67785076e-01,
#        -4.67785076e-01,  7.32214924e-01, -6.77850755e-02, -6.77850755e-02,
#         9.32214924e-01,  1.33221492e+00, -1.06778508e+00,  7.32214924e-01,
#        -1.66778508e+00,  1.32214924e-01,  1.93221492e+00, -3.06778508e+00,
#         1.33221492e+00,  7.32214924e-01,  3.32214924e-01, -6.77850755e-02,
#         1.32214924e-01, -2.67785076e-01, -2.67785076e-01,  1.32214924e-01,
#        -6.77850755e-02,  3.32214924e-01,  7.32214924e-01,  1.33221492e+00,
#         6.13221492e+00,  1.11322149e+01,  1.59322149e+01,  2.09322149e+01,
#         2.55322149e+01,  3.05322149e+01,  3.55322149e+01,  4.05322149e+01,
#         4.55322149e+01,  5.05322149e+01,  5.55322149e+01,  6.05322149e+01,
#         6.55322149e+01,  7.05322149e+01,  7.55322149e+01,  8.05322149e+01,
#         8.53322149e+01,  9.03322149e+01,  9.53322149e+01,  1.00332215e+02])

# %%
xps[:,0,0]
# Out:
# array([-0.06778508, -0.46778508,  1.33221492,  0.93221492, -0.26778508,
#        -1.26778508,  0.53221492,  0.93221492,  0.93221492, -0.26778508,
#        -1.26778508,  0.33221492,  1.33221492, -0.66778508,  1.73221492,
#        -0.06778508,  0.33221492,  0.33221492,  0.13221492, -0.86778508,
#        -0.26778508, -0.06778508, -0.86778508,  1.73221492, -0.46778508,
#        -0.46778508,  0.13221492, -0.66778508, -0.26778508, -0.06778508,
#        -0.06778508, -0.06778508,  0.13221492,  1.13221492,  0.73221492,
#         0.73221492,  1.33221492, -1.46778508,  1.53221492, -0.66778508,
#         1.73221492, -1.86778508,  2.33221492, -1.86778508,  1.73221492,
#        -0.66778508,  1.73221492, -1.86778508,  2.13221492, -1.46778508,
#         2.33221492, -2.66778508,  2.13221492, -1.46778508,  1.73221492,
#        -0.46778508, -0.46778508,  0.73221492, -0.06778508, -0.06778508,
#         0.93221492,  1.33221492, -1.06778508,  0.73221492, -1.66778508,
#         0.13221492,  1.93221492, -3.06778508,  1.33221492,  0.73221492,
#         0.33221492, -0.06778508,  0.13221492, -0.26778508, -0.26778508,
#         0.13221492, -0.06778508,  0.33221492,  0.73221492,  1.33221492,
#         6.13221492,  1.13221492,  0.93221492,  0.33221492,  0.53221492,
#         0.93221492,  0.33221492, -1.46778508,  0.13221492,  0.33221492,
#         0.53221492, -1.86778508,  0.53221492,  0.73221492, -0.86778508,
#        -0.26778508, -0.66778508, -0.06778508,  0.13221492, -0.26778508])

# %%
np.flip(rhos[:,0,0])
# Out:
# array([-2.72351853e-01, -3.52525319e-01,  3.55425361e+00, -4.33107469e-01,
#         3.65786270e-01,  6.75776423e-01,  1.44474568e+00, -1.07859397e+00,
#        -4.09545803e-01,  3.81922816e-01,  7.23647436e-01,  1.23742998e+00,
#        -4.45181754e-01, -2.08081069e+00,  1.24542972e-01, -1.35827479e+00,
#         4.20705041e-02,  1.17921049e-01,  1.27386710e-01,  1.90118001e-01,
#        -5.22865679e-01,  9.20370990e-01,  1.78389036e+00,  4.38280781e-01,
#        -1.70281710e+00,  5.97716382e-01,  2.52542326e-01,  3.13354450e-01,
#         1.56775892e-01,  2.67062882e+00, -8.46050993e-01, -2.14360443e-03,
#         9.29117772e-01, -1.04098977e+00,  3.90326214e-01,  5.08967463e-01,
#        -2.52902972e-01, -2.16958642e+00, -1.96515778e+00, -1.82077548e+00,
#        -4.26961162e-01, -6.87398838e-01,  6.44059886e-02, -7.78122950e-01,
#         7.46651881e-01, -1.74445974e+00, -3.52407919e-01, -5.83033503e-01,
#         1.78082263e-01, -1.18744986e+00,  1.51041104e+00,  1.34911949e-01,
#        -1.69398028e+00,  2.89778020e+00,  5.61442560e-01, -1.60943447e+00,
#         6.33790199e-01,  1.87715714e-01,  5.44919934e-01, -3.41087727e+00,
#         1.11745913e-03, -5.99555841e-02,  2.94248807e+00, -3.36060196e+00,
#         6.48326601e-01,  1.48036759e+00,  4.22831464e+00,  3.44147129e-01,
#        -4.83276217e+00, -8.41183466e-01, -8.92202226e-01, -9.43581199e-01,
#        -7.42388313e-02,  1.82707180e-01,  2.47007544e+00, -1.68641489e-01,
#         7.80347091e-02,  8.01152215e-01,  5.90441270e-01, -1.48459780e-01,
#         3.68910189e-01, -1.49766385e+00,  2.07417049e+00, -6.05542116e+00,
#         4.40740349e+00, -2.44783690e+00,  7.87904711e-01, -1.41053008e-03,
#        -7.82717179e-01,  2.43462203e+00, -4.44373742e+00,  1.37062770e+00,
#        -3.06164827e-01, -3.61641339e-01,  1.48279304e+00, -5.07230941e+00,
#         6.21638717e+00, -1.62474044e+00,  4.30179652e-01,  3.37883657e-01])

# %%
rhops[:,0,0]
# Out:
# array([-2.72351853e-01, -3.52525319e-01,  3.55425361e+00, -4.33107469e-01,
#         3.65786270e-01,  6.75776423e-01,  1.44474568e+00, -1.07859397e+00,
#        -4.09545803e-01,  3.81922816e-01,  7.23647436e-01,  1.23742998e+00,
#        -4.45181754e-01, -2.08081069e+00,  1.24542972e-01, -1.35827479e+00,
#         4.20705041e-02,  1.17921049e-01,  1.27386710e-01,  1.90118001e-01,
#        -5.22865679e-01,  9.20370990e-01,  1.78389036e+00,  4.38280781e-01,
#        -1.70281710e+00,  5.97716382e-01,  2.52542326e-01,  3.13354450e-01,
#         1.56775892e-01,  2.67062882e+00, -8.46050993e-01, -2.14360443e-03,
#         9.29117772e-01, -1.04098977e+00,  3.90326214e-01,  5.08967463e-01,
#        -2.52902972e-01, -2.16958642e+00, -1.96515778e+00, -1.82077548e+00,
#        -4.26961162e-01, -6.87398838e-01,  6.44059886e-02, -7.78122950e-01,
#         7.46651881e-01, -1.74445974e+00, -3.52407919e-01, -5.83033503e-01,
#         1.78082263e-01, -1.18744986e+00,  1.51041104e+00,  1.34911949e-01,
#        -1.69398028e+00,  2.89778020e+00,  5.61442560e-01, -1.60943447e+00,
#         6.33790199e-01,  1.87715714e-01,  5.44919934e-01, -3.41087727e+00,
#         1.11745913e-03, -5.99555841e-02,  2.94248807e+00, -3.36060196e+00,
#         6.48326601e-01,  1.48036759e+00,  4.22831464e+00,  3.44147129e-01,
#        -4.83276217e+00, -8.41183466e-01, -8.92202226e-01, -9.43581199e-01,
#        -7.42388313e-02,  1.82707180e-01,  2.47007544e+00, -1.68641489e-01,
#         7.80347091e-02,  8.01152215e-01,  5.90441270e-01, -1.48459780e-01,
#         3.68905897e-01,  3.08888281e+01, -3.38167172e-01,  6.24993273e-01,
#         7.87751449e-01,  4.12008152e-01, -1.71408072e+00, -2.63492013e-01,
#         1.57911640e+00,  3.63333762e+00,  4.23779561e+00, -3.37919278e+00,
#         1.52834933e+00, -1.52272796e+00, -1.07318604e+00,  1.90233184e+00,
#        -2.91666279e-02, -5.39945967e-01, -1.49953805e-01, -5.46045830e-02])
