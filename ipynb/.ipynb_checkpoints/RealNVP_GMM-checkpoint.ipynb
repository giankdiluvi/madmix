# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.metrics import confusion_matrix
import sys,time
sys.path.insert(1, '../discrete_mixflows/')
from discrete_mixflows import *
import gibbs
from concrete import *

plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams["figure.figsize"]=15,7.5
plt.rcParams.update({'font.size': 24})

# %%
# data generation
np.random.seed(2023)
N=1000
K=3
true_mu=np.array([-7.5,0,7.5])
true_tau=0.4*np.ones(3)
true_w=np.array([0.2,0.5,0.3])

x=np.random.choice(np.arange(K,dtype=int),size=N,p=true_w)
y=true_mu[x]+np.random.randn(N)/np.sqrt(true_tau[x])

# %%
plt.hist(y,bins=50,alpha=0.5,ec='black',density=True)
plt.xlabel(r'$y$')
plt.ylabel('Density')
plt.title('Sample histogram');

# %% [markdown]
# ## Real NVP with Concrete for labels

# %%
import torch
import torch.distributions

# %%
class GMMRef(Distribution):
    def __init__(self, N,K,tau0=1.,temp=1.):
        self.relcat = ExpRelaxedCategorical(torch([temp]),torch.ones(K)/K)
        self.gauss = torch.distributions.MultivariateNormal(torch.zeros(K), torch.eye(K)/np.sqrt(tau0))
        
    def log_prob(self, value):
        mvn_lp = self.gauss.log_prob(value[...,:K])
        relcat_lp = torch.zeros(value.shape[0])
        for n in range(N): relcat_lp += self.relcat.log_prob(value[:,K+n*K+torch.arange(0,K)])
        return relcat_lp+mvn_lp

    def sample(self,sample_shape=torch.Size()):
        relcat_sample=self.relcat.sample((sample_shape,N))
        mvn_sample=self.gauss.sample(sample_shape)
        return torch.hstack(mvn_sample,relcat_sample)

# %%
tau0=0.1
mvn=torch.distributions.MultivariateNormal(torch.zeros(K), torch.eye(K)/np.sqrt(tau0))

# %%
mvn.sample((5,)).shape
# Out:
# torch.Size([5, 3])

# %%
cat=torch.distributions.Categorical(torch.ones((N,K))/K)

# %%
cat._num_events
# Out:
# 3

# %%
relcat = ExpRelaxedCategorical(torch.tensor([0.5]),torch.ones(K)/K)

# %%
tmp_sample=relcat.sample((5,1))
print(tmp_sample.shape)
print(relcat.log_prob(tmp_sample).shape)
tmp_sample=np.exp(np.squeeze(tmp_sample.detach().numpy())) # expConcrete->Concrete
tmp_sample=tmp_sample/np.sum(tmp_sample,axis=-1)[...,np.newaxis] # normalize probs
tmp_sample=np.argmax(tmp_sample,axis=-1) # rounding Concrete
tmp_sample
# Out:
# torch.Size([5, 1, 3])
# torch.Size([5, 1])
# array([2, 0, 2, 1, 0])
